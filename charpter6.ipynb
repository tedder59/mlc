# %%
from tvm.ir.module import IRModule
from tvm.script import relax as R
from tvm.script import tir as T
from tvm import relax
import numpy as np
import tvm

# %%
@tvm.script.ir_module
class MyModuleVecAdd:
    @T.prim_func
    def main(A: T.Buffer[(1024,), "float32"],
             B: T.Buffer[(1024,), "float32"],
             C: T.Buffer[(1024,), "float32"]) -> None:
        T.func_attr({"global_symbol": "main", "tir.noalias": True})
        for i in T.grid(1024):
            with T.block("C"):
                vi = T.axis.remap("S", [i])
                C[vi] = A[vi] + B[vi]

# %%
sch = tvm.tir.Schedule(MyModuleVecAdd)
block_C = sch.get_block("C")
i, = sch.get_loops(block=block_C)
i0, i1 = sch.split(i, [None, 128])
sch.mod.show()
# Out:
# /workspace/relax/python/tvm/script/highlight.py:116: UserWarning: No module named 'black'
# To print formatted TVM script, please install the formatter 'Black':
# /opt/conda/bin/python3.8 -m pip install "black==22.3.0" --upgrade --user
#   warnings.warn(
# <div class="highlight" style="background: "><pre style="line-height: 125%;"><span></span><span style="color: #AA22FF">@tvm</span><span style="color: #AA22FF; font-weight: bold">.</span>script<span style="color: #AA22FF; font-weight: bold">.</span>ir_module
# <span style="color: #008000; font-weight: bold">class</span> <span style="color: #0000FF; font-weight: bold">Module</span>:
#     <span style="color: #AA22FF">@T</span><span style="color: #AA22FF; font-weight: bold">.</span>prim_func
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">main</span>(A: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer[<span style="color: #008000">1024</span>, <span style="color: #BA2121">&quot;float32&quot;</span>], B: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer[<span style="color: #008000">1024</span>, <span style="color: #BA2121">&quot;float32&quot;</span>], C: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer[<span style="color: #008000">1024</span>, <span style="color: #BA2121">&quot;float32&quot;</span>]):
#         <span style="color: #007979; font-style: italic"># function attr dict</span>
#         T<span style="color: #AA22FF; font-weight: bold">.</span>func_attr({<span style="color: #BA2121">&quot;tir.noalias&quot;</span>: <span style="color: #008000; font-weight: bold">True</span>, <span style="color: #BA2121">&quot;global_symbol&quot;</span>: <span style="color: #BA2121">&quot;main&quot;</span>})
#         <span style="color: #007979; font-style: italic"># body</span>
#         <span style="color: #007979; font-style: italic"># with T.block(&quot;root&quot;)</span>
#         <span style="color: #008000; font-weight: bold">for</span> i_0, i_1 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>grid(<span style="color: #008000">8</span>, <span style="color: #008000">128</span>):
#             <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #AA22FF; font-weight: bold">.</span>block(<span style="color: #BA2121">&quot;C&quot;</span>):
#                 vi <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>axis<span style="color: #AA22FF; font-weight: bold">.</span>spatial(<span style="color: #008000">1024</span>, i_0 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">128</span> <span style="color: #AA22FF; font-weight: bold">+</span> i_1)
#                 T<span style="color: #AA22FF; font-weight: bold">.</span>reads(A[vi], B[vi])
#                 T<span style="color: #AA22FF; font-weight: bold">.</span>writes(C[vi])
#                 C[vi] <span style="color: #AA22FF; font-weight: bold">=</span> A[vi] <span style="color: #AA22FF; font-weight: bold">+</span> B[vi]
#
# </pre></div>

# %%
sch.bind(i0, "blockIdx.x")
sch.bind(i1, "threadIdx.x")
sch.mod.show()
# Out:
# /workspace/relax/python/tvm/script/highlight.py:116: UserWarning: No module named 'black'
# To print formatted TVM script, please install the formatter 'Black':
# /opt/conda/bin/python3.8 -m pip install "black==22.3.0" --upgrade --user
#   warnings.warn(
# <div class="highlight" style="background: "><pre style="line-height: 125%;"><span></span><span style="color: #AA22FF">@tvm</span><span style="color: #AA22FF; font-weight: bold">.</span>script<span style="color: #AA22FF; font-weight: bold">.</span>ir_module
# <span style="color: #008000; font-weight: bold">class</span> <span style="color: #0000FF; font-weight: bold">Module</span>:
#     <span style="color: #AA22FF">@T</span><span style="color: #AA22FF; font-weight: bold">.</span>prim_func
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">main</span>(A: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer[<span style="color: #008000">1024</span>, <span style="color: #BA2121">&quot;float32&quot;</span>], B: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer[<span style="color: #008000">1024</span>, <span style="color: #BA2121">&quot;float32&quot;</span>], C: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer[<span style="color: #008000">1024</span>, <span style="color: #BA2121">&quot;float32&quot;</span>]):
#         <span style="color: #007979; font-style: italic"># function attr dict</span>
#         T<span style="color: #AA22FF; font-weight: bold">.</span>func_attr({<span style="color: #BA2121">&quot;tir.noalias&quot;</span>: <span style="color: #008000; font-weight: bold">True</span>, <span style="color: #BA2121">&quot;global_symbol&quot;</span>: <span style="color: #BA2121">&quot;main&quot;</span>})
#         <span style="color: #007979; font-style: italic"># body</span>
#         <span style="color: #007979; font-style: italic"># with T.block(&quot;root&quot;)</span>
#         <span style="color: #008000; font-weight: bold">for</span> i_0 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>thread_binding(<span style="color: #008000">8</span>, thread<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;blockIdx.x&quot;</span>):
#             <span style="color: #008000; font-weight: bold">for</span> i_1 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>thread_binding(<span style="color: #008000">128</span>, thread<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;threadIdx.x&quot;</span>):
#                 <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #AA22FF; font-weight: bold">.</span>block(<span style="color: #BA2121">&quot;C&quot;</span>):
#                     vi <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>axis<span style="color: #AA22FF; font-weight: bold">.</span>spatial(<span style="color: #008000">1024</span>, i_0 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">128</span> <span style="color: #AA22FF; font-weight: bold">+</span> i_1)
#                     T<span style="color: #AA22FF; font-weight: bold">.</span>reads(A[vi], B[vi])
#                     T<span style="color: #AA22FF; font-weight: bold">.</span>writes(C[vi])
#                     C[vi] <span style="color: #AA22FF; font-weight: bold">=</span> A[vi] <span style="color: #AA22FF; font-weight: bold">+</span> B[vi]
#
# </pre></div>

# %%
rt_mod = tvm.build(sch.mod, target="cuda")

A_np = np.random.uniform(size=(1024,)).astype(np.float32)
B_np = np.random.uniform(size=(1024,)).astype(np.float32)

A_nd = tvm.nd.array(A_np, tvm.cuda(0))
B_nd = tvm.nd.array(B_np, tvm.cuda(0))
C_nd = tvm.nd.array(np.zeros((1024,), dtype="float32"), tvm.cuda(0))

rt_mod["main"](A_nd, B_nd, C_nd)
print(A_nd)
print(B_nd)
print(C_nd)
# Out:
# [0.7697751  0.1894259  0.15973441 ... 0.71162534 0.25710225 0.54057324]
# [0.11879353 0.5710991  0.7792158  ... 0.17648411 0.8976469  0.04839446]
# [0.88856864 0.760525   0.93895024 ... 0.88810945 1.1547492  0.5889677 ]

# %%
@tvm.script.ir_module
class MyModuleWindowSum:
    @T.prim_func
    def main(A: T.Buffer[(1026,), "float32"],
             B: T.Buffer[(1024,), "float32"]) -> None:
        T.func_attr({"global_symbol": "main", "tir.noalias": True})
        for i in T.grid(1024):
            with T.block("C"):
                vi = T.axis.remap("S", [i])
                B[vi] = A[vi] + A[vi + 1] + A[vi + 2]

# %%
sch = tvm.tir.Schedule(MyModuleWindowSum)
nthread = 128
block = sch.get_block("C")
i, = sch.get_loops(block)
i0, i1 = sch.split(i, [None, nthread])

sch.bind(i0, "blockIdx.x")
sch.bind(i1, "threadIdx.x")
sch.mod.show()
# Out:
# /workspace/relax/python/tvm/script/highlight.py:116: UserWarning: No module named 'black'
# To print formatted TVM script, please install the formatter 'Black':
# /opt/conda/bin/python3.8 -m pip install "black==22.3.0" --upgrade --user
#   warnings.warn(
# <div class="highlight" style="background: "><pre style="line-height: 125%;"><span></span><span style="color: #AA22FF">@tvm</span><span style="color: #AA22FF; font-weight: bold">.</span>script<span style="color: #AA22FF; font-weight: bold">.</span>ir_module
# <span style="color: #008000; font-weight: bold">class</span> <span style="color: #0000FF; font-weight: bold">Module</span>:
#     <span style="color: #AA22FF">@T</span><span style="color: #AA22FF; font-weight: bold">.</span>prim_func
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">main</span>(A: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer[<span style="color: #008000">1026</span>, <span style="color: #BA2121">&quot;float32&quot;</span>], B: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer[<span style="color: #008000">1024</span>, <span style="color: #BA2121">&quot;float32&quot;</span>]):
#         <span style="color: #007979; font-style: italic"># function attr dict</span>
#         T<span style="color: #AA22FF; font-weight: bold">.</span>func_attr({<span style="color: #BA2121">&quot;tir.noalias&quot;</span>: <span style="color: #008000; font-weight: bold">True</span>, <span style="color: #BA2121">&quot;global_symbol&quot;</span>: <span style="color: #BA2121">&quot;main&quot;</span>})
#         <span style="color: #007979; font-style: italic"># body</span>
#         <span style="color: #007979; font-style: italic"># with T.block(&quot;root&quot;)</span>
#         <span style="color: #008000; font-weight: bold">for</span> i_0 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>thread_binding(<span style="color: #008000">8</span>, thread<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;blockIdx.x&quot;</span>):
#             <span style="color: #008000; font-weight: bold">for</span> i_1 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>thread_binding(<span style="color: #008000">128</span>, thread<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;threadIdx.x&quot;</span>):
#                 <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #AA22FF; font-weight: bold">.</span>block(<span style="color: #BA2121">&quot;C&quot;</span>):
#                     vi <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>axis<span style="color: #AA22FF; font-weight: bold">.</span>spatial(<span style="color: #008000">1024</span>, i_0 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">128</span> <span style="color: #AA22FF; font-weight: bold">+</span> i_1)
#                     T<span style="color: #AA22FF; font-weight: bold">.</span>reads(A[vi : vi <span style="color: #AA22FF; font-weight: bold">+</span> <span style="color: #008000">3</span>])
#                     T<span style="color: #AA22FF; font-weight: bold">.</span>writes(B[vi])
#                     B[vi] <span style="color: #AA22FF; font-weight: bold">=</span> A[vi] <span style="color: #AA22FF; font-weight: bold">+</span> A[vi <span style="color: #AA22FF; font-weight: bold">+</span> <span style="color: #008000">1</span>] <span style="color: #AA22FF; font-weight: bold">+</span> A[vi <span style="color: #AA22FF; font-weight: bold">+</span> <span style="color: #008000">2</span>]
#
# </pre></div>

# %%
A_shared = sch.cache_read(block, read_buffer_index=0, storage_scope="shared")
sch.compute_at(A_shared, i1)
sch.mod.show()
# Out:
# /workspace/relax/python/tvm/script/highlight.py:116: UserWarning: No module named 'black'
# To print formatted TVM script, please install the formatter 'Black':
# /opt/conda/bin/python3.8 -m pip install "black==22.3.0" --upgrade --user
#   warnings.warn(
# <div class="highlight" style="background: "><pre style="line-height: 125%;"><span></span><span style="color: #AA22FF">@tvm</span><span style="color: #AA22FF; font-weight: bold">.</span>script<span style="color: #AA22FF; font-weight: bold">.</span>ir_module
# <span style="color: #008000; font-weight: bold">class</span> <span style="color: #0000FF; font-weight: bold">Module</span>:
#     <span style="color: #AA22FF">@T</span><span style="color: #AA22FF; font-weight: bold">.</span>prim_func
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">main</span>(A: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer[<span style="color: #008000">1026</span>, <span style="color: #BA2121">&quot;float32&quot;</span>], B: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer[<span style="color: #008000">1024</span>, <span style="color: #BA2121">&quot;float32&quot;</span>]):
#         <span style="color: #007979; font-style: italic"># function attr dict</span>
#         T<span style="color: #AA22FF; font-weight: bold">.</span>func_attr({<span style="color: #BA2121">&quot;tir.noalias&quot;</span>: <span style="color: #008000; font-weight: bold">True</span>, <span style="color: #BA2121">&quot;global_symbol&quot;</span>: <span style="color: #BA2121">&quot;main&quot;</span>})
#         <span style="color: #007979; font-style: italic"># body</span>
#         <span style="color: #007979; font-style: italic"># with T.block(&quot;root&quot;)</span>
#         A_shared <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>alloc_buffer([<span style="color: #008000">1026</span>], dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>, scope<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;shared&quot;</span>)
#         <span style="color: #008000; font-weight: bold">for</span> i_0 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>thread_binding(<span style="color: #008000">8</span>, thread<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;blockIdx.x&quot;</span>):
#             <span style="color: #008000; font-weight: bold">for</span> i_1 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>thread_binding(<span style="color: #008000">128</span>, thread<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;threadIdx.x&quot;</span>):
#                 <span style="color: #008000; font-weight: bold">for</span> ax0 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>serial(<span style="color: #008000">130</span>):
#                     <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #AA22FF; font-weight: bold">.</span>block(<span style="color: #BA2121">&quot;A_shared&quot;</span>):
#                         v0 <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>axis<span style="color: #AA22FF; font-weight: bold">.</span>spatial(<span style="color: #008000">1026</span>, i_0 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">128</span> <span style="color: #AA22FF; font-weight: bold">+</span> ax0)
#                         T<span style="color: #AA22FF; font-weight: bold">.</span>reads(A[v0])
#                         T<span style="color: #AA22FF; font-weight: bold">.</span>writes(A_shared[v0])
#                         A_shared[v0] <span style="color: #AA22FF; font-weight: bold">=</span> A[v0]
#                 <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #AA22FF; font-weight: bold">.</span>block(<span style="color: #BA2121">&quot;C&quot;</span>):
#                     vi <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>axis<span style="color: #AA22FF; font-weight: bold">.</span>spatial(<span style="color: #008000">1024</span>, i_0 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">128</span> <span style="color: #AA22FF; font-weight: bold">+</span> i_1)
#                     T<span style="color: #AA22FF; font-weight: bold">.</span>reads(A_shared[vi : vi <span style="color: #AA22FF; font-weight: bold">+</span> <span style="color: #008000">3</span>])
#                     T<span style="color: #AA22FF; font-weight: bold">.</span>writes(B[vi])
#                     B[vi] <span style="color: #AA22FF; font-weight: bold">=</span> A_shared[vi] <span style="color: #AA22FF; font-weight: bold">+</span> A_shared[vi <span style="color: #AA22FF; font-weight: bold">+</span> <span style="color: #008000">1</span>] <span style="color: #AA22FF; font-weight: bold">+</span> A_shared[vi <span style="color: #AA22FF; font-weight: bold">+</span> <span style="color: #008000">2</span>]
#
# </pre></div>

# %%
ax = sch.get_loops(A_shared)[-1]
ax0, ax1 = sch.split(ax, [None, nthread])
sch.bind(ax1, "threadIdx.x")
sch.mod.show()
# Out:
# /workspace/relax/python/tvm/script/highlight.py:116: UserWarning: No module named 'black'
# To print formatted TVM script, please install the formatter 'Black':
# /opt/conda/bin/python3.8 -m pip install "black==22.3.0" --upgrade --user
#   warnings.warn(
# <div class="highlight" style="background: "><pre style="line-height: 125%;"><span></span><span style="color: #AA22FF">@tvm</span><span style="color: #AA22FF; font-weight: bold">.</span>script<span style="color: #AA22FF; font-weight: bold">.</span>ir_module
# <span style="color: #008000; font-weight: bold">class</span> <span style="color: #0000FF; font-weight: bold">Module</span>:
#     <span style="color: #AA22FF">@T</span><span style="color: #AA22FF; font-weight: bold">.</span>prim_func
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">main</span>(A: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer[<span style="color: #008000">1026</span>, <span style="color: #BA2121">&quot;float32&quot;</span>], B: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer[<span style="color: #008000">1024</span>, <span style="color: #BA2121">&quot;float32&quot;</span>]):
#         <span style="color: #007979; font-style: italic"># function attr dict</span>
#         T<span style="color: #AA22FF; font-weight: bold">.</span>func_attr({<span style="color: #BA2121">&quot;tir.noalias&quot;</span>: <span style="color: #008000; font-weight: bold">True</span>, <span style="color: #BA2121">&quot;global_symbol&quot;</span>: <span style="color: #BA2121">&quot;main&quot;</span>})
#         <span style="color: #007979; font-style: italic"># body</span>
#         <span style="color: #007979; font-style: italic"># with T.block(&quot;root&quot;)</span>
#         A_shared <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>alloc_buffer([<span style="color: #008000">1026</span>], dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>, scope<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;shared&quot;</span>)
#         <span style="color: #008000; font-weight: bold">for</span> i_0 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>thread_binding(<span style="color: #008000">8</span>, thread<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;blockIdx.x&quot;</span>):
#             <span style="color: #008000; font-weight: bold">for</span> i_1 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>thread_binding(<span style="color: #008000">128</span>, thread<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;threadIdx.x&quot;</span>):
#                 <span style="color: #008000; font-weight: bold">for</span> ax0_0 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>serial(<span style="color: #008000">2</span>):
#                     <span style="color: #008000; font-weight: bold">for</span> ax0_1 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>thread_binding(<span style="color: #008000">128</span>, thread<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;threadIdx.x&quot;</span>):
#                         <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #AA22FF; font-weight: bold">.</span>block(<span style="color: #BA2121">&quot;A_shared&quot;</span>):
#                             T<span style="color: #AA22FF; font-weight: bold">.</span>where(ax0_0 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">128</span> <span style="color: #AA22FF; font-weight: bold">+</span> ax0_1 <span style="color: #AA22FF; font-weight: bold">&lt;</span> <span style="color: #008000">130</span>)
#                             v0 <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>axis<span style="color: #AA22FF; font-weight: bold">.</span>spatial(<span style="color: #008000">1026</span>, i_0 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">128</span> <span style="color: #AA22FF; font-weight: bold">+</span> (ax0_0 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">128</span> <span style="color: #AA22FF; font-weight: bold">+</span> ax0_1))
#                             T<span style="color: #AA22FF; font-weight: bold">.</span>reads(A[v0])
#                             T<span style="color: #AA22FF; font-weight: bold">.</span>writes(A_shared[v0])
#                             A_shared[v0] <span style="color: #AA22FF; font-weight: bold">=</span> A[v0]
#                 <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #AA22FF; font-weight: bold">.</span>block(<span style="color: #BA2121">&quot;C&quot;</span>):
#                     vi <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>axis<span style="color: #AA22FF; font-weight: bold">.</span>spatial(<span style="color: #008000">1024</span>, i_0 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">128</span> <span style="color: #AA22FF; font-weight: bold">+</span> i_1)
#                     T<span style="color: #AA22FF; font-weight: bold">.</span>reads(A_shared[vi : vi <span style="color: #AA22FF; font-weight: bold">+</span> <span style="color: #008000">3</span>])
#                     T<span style="color: #AA22FF; font-weight: bold">.</span>writes(B[vi])
#                     B[vi] <span style="color: #AA22FF; font-weight: bold">=</span> A_shared[vi] <span style="color: #AA22FF; font-weight: bold">+</span> A_shared[vi <span style="color: #AA22FF; font-weight: bold">+</span> <span style="color: #008000">1</span>] <span style="color: #AA22FF; font-weight: bold">+</span> A_shared[vi <span style="color: #AA22FF; font-weight: bold">+</span> <span style="color: #008000">2</span>]
#
# </pre></div>

# %%
rt_mod = tvm.build(sch.mod, target="cuda")
print(rt_mod.imported_modules[0].get_source())
# Out:
# #ifdef _WIN32
#   using uint = unsigned int;
#   using uchar = unsigned char;
#   using ushort = unsigned short;
#   using int64_t = long long;
#   using uint64_t = unsigned long long;
# #else
#   #define uint unsigned int
#   #define uchar unsigned char
#   #define ushort unsigned short
#   #define int64_t long long
#   #define uint64_t unsigned long long
# #endif
# extern "C" __global__ void __launch_bounds__(128) main_kernel0(float* __restrict__ A, float* __restrict__ B) {
#   __shared__ float A_shared[130];
#   for (int ax0_0 = 0; ax0_0 < 2; ++ax0_0) {
#     if (((ax0_0 * 64) + (((int)threadIdx.x) >> 1)) < 65) {
#       A_shared[((ax0_0 * 128) + ((int)threadIdx.x))] = A[(((((int)blockIdx.x) * 128) + (ax0_0 * 128)) + ((int)threadIdx.x))];
#     }
#   }
#   __syncthreads();
#   B[((((int)blockIdx.x) * 128) + ((int)threadIdx.x))] = ((A_shared[((int)threadIdx.x)] + A_shared[(((int)threadIdx.x) + 1)]) + A_shared[(((int)threadIdx.x) + 2)]);
# }

# %%
rt_mod = tvm.build(sch.mod, target="metal")
print(rt_mod.imported_modules[0].get_source())
# Out:
# [05:05:08] /workspace/relax/src/target/opt/build_metal_off.cc:31: Warning: Metal runtime not enabled, return a source module...
# // Function: main_kernel0
# #include <metal_stdlib>
# using namespace metal;
#
# union __TVMArgUnion {
#  int v_int[2];
# };
#
# kernel void main_kernel0(  device float* A [[ buffer(0) ]],
#   device float* B [[ buffer(1) ]],
#   uint blockIdx [[threadgroup_position_in_grid]],
#   uint threadIdx [[thread_position_in_threadgroup]]
# ) {
#   threadgroup float A_shared[130];
#   for (int ax0_0 = 0; ax0_0 < 2; ++ax0_0) {
#     if (((ax0_0 * 64) + (((int)threadIdx) >> 1)) < 65) {
#       A_shared[((ax0_0 * 128) + ((int)threadIdx))] = A[(((((int)blockIdx) * 128) + (ax0_0 * 128)) + ((int)threadIdx))];
#     }
#   }
#   threadgroup_barrier(mem_flags::mem_threadgroup);
#   B[((((int)blockIdx) * 128) + ((int)threadIdx))] = ((A_shared[((int)threadIdx)] + A_shared[(((int)threadIdx) + 1)]) + A_shared[(((int)threadIdx) + 2)]);
# }

# %%
@tvm.script.ir_module
class MyModuleMatMul:
    @T.prim_func
    def main(A: T.Buffer[(1024, 1024), "float32"],
             B: T.Buffer[(1024, 1024), "float32"],
             C: T.Buffer[(1024, 1024), "float32"]) -> None:
        T.func_attr({"global_symbol": "main", "tir.noalias": True})
        for i, j, k in T.grid(1024, 1024, 1024):
            with T.block("C"):
                vi, vj, vk = T.axis.remap("SSR", [i, j, k])
                with T.init():
                    C[vi, vj] = 0
                C[vi, vj] = C[vi, vj] + A[vi, vk] * B[vk, vj]

# %%
def blocking(sch, tile_local_y, tile_local_x, tile_block_y, tile_block_x, tile_k):
    block = sch.get_block("C")
    local = sch.cache_write(block, 0, "local")
    i, j, k = sch.get_loops(block)
    
    i0, i1, i2 = sch.split(i, [None, tile_block_y, tile_block_y])
    j0, j1, j2 = sch.split(j, [None, tile_block_x, tile_block_x])
    k0, k1 = sch.split(k, [None, tile_k])
    
    sch.unroll(k1)
    sch.reorder(i0, j0, i1, j1, k0, k1, i2, j2)
    sch.reverse_compute_at(local, j1)
    
    sch.bind(i0, "blockIdx.y")
    sch.bind(j0, "blockIdx.x")
    sch.bind(i1, "threadIdx.y")
    sch.bind(j1, "threadIdx.x")
    
    sch.decompose_reduction(block, k0)
    return sch

sch = tvm.tir.Schedule(MyModuleMatMul)
sch = blocking(sch, 8, 8, 8, 8, 4)
sch.mod.show()
# Out:
# /workspace/relax/python/tvm/script/highlight.py:116: UserWarning: No module named 'black'
# To print formatted TVM script, please install the formatter 'Black':
# /opt/conda/bin/python3.8 -m pip install "black==22.3.0" --upgrade --user
#   warnings.warn(
# <div class="highlight" style="background: "><pre style="line-height: 125%;"><span></span><span style="color: #AA22FF">@tvm</span><span style="color: #AA22FF; font-weight: bold">.</span>script<span style="color: #AA22FF; font-weight: bold">.</span>ir_module
# <span style="color: #008000; font-weight: bold">class</span> <span style="color: #0000FF; font-weight: bold">Module</span>:
#     <span style="color: #AA22FF">@T</span><span style="color: #AA22FF; font-weight: bold">.</span>prim_func
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">main</span>(A: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer[(<span style="color: #008000">1024</span>, <span style="color: #008000">1024</span>), <span style="color: #BA2121">&quot;float32&quot;</span>], B: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer[(<span style="color: #008000">1024</span>, <span style="color: #008000">1024</span>), <span style="color: #BA2121">&quot;float32&quot;</span>], C: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer[(<span style="color: #008000">1024</span>, <span style="color: #008000">1024</span>), <span style="color: #BA2121">&quot;float32&quot;</span>]):
#         <span style="color: #007979; font-style: italic"># function attr dict</span>
#         T<span style="color: #AA22FF; font-weight: bold">.</span>func_attr({<span style="color: #BA2121">&quot;tir.noalias&quot;</span>: <span style="color: #008000; font-weight: bold">True</span>, <span style="color: #BA2121">&quot;global_symbol&quot;</span>: <span style="color: #BA2121">&quot;main&quot;</span>})
#         <span style="color: #007979; font-style: italic"># body</span>
#         <span style="color: #007979; font-style: italic"># with T.block(&quot;root&quot;)</span>
#         C_local <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>alloc_buffer([<span style="color: #008000">1024</span>, <span style="color: #008000">1024</span>], dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>, scope<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;local&quot;</span>)
#         <span style="color: #008000; font-weight: bold">for</span> i_0 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>thread_binding(<span style="color: #008000">16</span>, thread<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;blockIdx.y&quot;</span>):
#             <span style="color: #008000; font-weight: bold">for</span> j_0 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>thread_binding(<span style="color: #008000">16</span>, thread<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;blockIdx.x&quot;</span>):
#                 <span style="color: #008000; font-weight: bold">for</span> i_1 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>thread_binding(<span style="color: #008000">8</span>, thread<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;threadIdx.y&quot;</span>):
#                     <span style="color: #008000; font-weight: bold">for</span> j_1 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>thread_binding(<span style="color: #008000">8</span>, thread<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;threadIdx.x&quot;</span>):
#                         <span style="color: #008000; font-weight: bold">for</span> i_2_init, j_2_init <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>grid(<span style="color: #008000">8</span>, <span style="color: #008000">8</span>):
#                             <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #AA22FF; font-weight: bold">.</span>block(<span style="color: #BA2121">&quot;C_init&quot;</span>):
#                                 vi <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>axis<span style="color: #AA22FF; font-weight: bold">.</span>spatial(<span style="color: #008000">1024</span>, i_0 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">64</span> <span style="color: #AA22FF; font-weight: bold">+</span> i_1 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">8</span> <span style="color: #AA22FF; font-weight: bold">+</span> i_2_init)
#                                 vj <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>axis<span style="color: #AA22FF; font-weight: bold">.</span>spatial(<span style="color: #008000">1024</span>, j_0 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">64</span> <span style="color: #AA22FF; font-weight: bold">+</span> j_1 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">8</span> <span style="color: #AA22FF; font-weight: bold">+</span> j_2_init)
#                                 T<span style="color: #AA22FF; font-weight: bold">.</span>reads()
#                                 T<span style="color: #AA22FF; font-weight: bold">.</span>writes(C_local[vi, vj])
#                                 C_local[vi, vj] <span style="color: #AA22FF; font-weight: bold">=</span> <span style="color: #008000">0</span>
#                         <span style="color: #008000; font-weight: bold">for</span> k_0 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>serial(<span style="color: #008000">256</span>):
#                             <span style="color: #008000; font-weight: bold">for</span> k_1 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>unroll(<span style="color: #008000">4</span>):
#                                 <span style="color: #008000; font-weight: bold">for</span> i_2, j_2 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>grid(<span style="color: #008000">8</span>, <span style="color: #008000">8</span>):
#                                     <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #AA22FF; font-weight: bold">.</span>block(<span style="color: #BA2121">&quot;C_update&quot;</span>):
#                                         vi <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>axis<span style="color: #AA22FF; font-weight: bold">.</span>spatial(<span style="color: #008000">1024</span>, i_0 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">64</span> <span style="color: #AA22FF; font-weight: bold">+</span> i_1 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">8</span> <span style="color: #AA22FF; font-weight: bold">+</span> i_2)
#                                         vj <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>axis<span style="color: #AA22FF; font-weight: bold">.</span>spatial(<span style="color: #008000">1024</span>, j_0 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">64</span> <span style="color: #AA22FF; font-weight: bold">+</span> j_1 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">8</span> <span style="color: #AA22FF; font-weight: bold">+</span> j_2)
#                                         vk <

# %%
rt_mod = tvm.build(sch.mod, target="cuda")
print(rt_mod.imported_modules[0].get_source())

A_np = np.random.uniform(size=(1024, 1024)).astype("float32")
B_np = np.random.uniform(size=(1024, 1024)).astype("float32")

A_nd = tvm.nd.array(A_np, tvm.cuda(0))
B_nd = tvm.nd.array(B_np, tvm.cuda(0))
C_nd = tvm.nd.array(np.zeros((1024, 1024), dtype="float32"), tvm.cuda(0))

flops = (1024 ** 3) * 2
evaluator = rt_mod.time_evaluator("main", tvm.cuda(0), number=10)
print("GEMM blocking: %f GFLOPS" %(flops / evaluator(A_nd, B_nd, C_nd).mean / 1e9))
# Out:
# #ifdef _WIN32
#   using uint = unsigned int;
#   using uchar = unsigned char;
#   using ushort = unsigned short;
#   using int64_t = long long;
#   using uint64_t = unsigned long long;
# #else
#   #define uint unsigned int
#   #define uchar unsigned char
#   #define ushort unsigned short
#   #define int64_t long long
#   #define uint64_t unsigned long long
# #endif
# extern "C" __global__ void __launch_bounds__(64) main_kernel0(float* __restrict__ A, float* __restrict__ B, float* __restrict__ C) {
#   float C_local[64];
#   for (int i_2_init = 0; i_2_init < 8; ++i_2_init) {
#     for (int j_2_init = 0; j_2_init < 8; ++j_2_init) {
#       C_local[((i_2_init * 8) + j_2_init)] = 0.000000e+00f;
#     }
#   }
#   for (int k_0 = 0; k_0 < 256; ++k_0) {
#     for (int i_2 = 0; i_2 < 8; ++i_2) {
#       for (int j_2 = 0; j_2 < 8; ++j_2) {
#         C_local[((i_2 * 8) + j_2)] = (C_local[((i_2 * 8) + j_2)] + (A[((((((int)blockIdx.y) * 65536) + (((int)threadIdx.y) * 8192)) + (i_2 * 1024)) + (k_0 * 4))] * B[((((k_0 * 4096) + (((int)blockIdx.x) * 64)) + (((int)threadIdx.x) * 8)) + j_2)]));
#       }
#     }
#     for (int i_2_1 = 0; i_2_1 < 8; ++i_2_1) {
#       for (int j_2_1 = 0; j_2_1 < 8; ++j_2_1) {
#         C_local[((i_2_1 * 8) + j_2_1)] = (C_local[((i_2_1 * 8) + j_2_1)] + (A[(((((((int)blockIdx.y) * 65536) + (((int)threadIdx.y) * 8192)) + (i_2_1 * 1024)) + (k_0 * 4)) + 1)] * B[(((((k_0 * 4096) + (((int)blockIdx.x) * 64)) + (((int)threadIdx.x) * 8)) + j_2_1) + 1024)]));
#       }
#     }
#     for (int i_2_2 = 0; i_2_2 < 8; ++i_2_2) {
#       for (int j_2_2 = 0; j_2_2 < 8; ++j_2_2) {
#         C_local[((i_2_2 * 8) + j_2_2)] = (C_local[((i_2_2 * 8) + j_2_2)] + (A[(((((((int)blockIdx.y) * 65536) + (((int)threadIdx.y) * 8192)) + (i_2_2 * 1024)) + (k_0 * 4)) + 2)] * B[(((((k_0 * 4096) + (((int)blockIdx.x) * 64)) + (((int)threadIdx.x) * 8)) + j_2_2) + 2048)]));
#       }
#     }
#     for (int i_2_3 = 0; i_2_3 < 8; ++i_2_3) {
#       for (int j_2_3 = 0; j_2_3 < 8; ++j_2_3) {
#         C_local[((i_2_3 * 8) + j_2_3)] = (C_local[((i_2_3 * 8) + j_2_3)] + (A[(((((((int)blockIdx.y) * 65536) + (((int)threadIdx.y) * 8192)) + (i_2_3 * 1024)) + (k_0 * 4)) + 3)] * B[(((((k_0 * 4096) + (((int)blockIdx.x) * 64)) + (((int)threadIdx.x) * 8)) + j_2_3) + 3072)]));
#       }
#     }
#   }
#   for (int ax0 = 0; ax0 < 8; ++ax0) {
#     for (int ax1 = 0; ax1 < 8; ++ax1) {
#       C[((((((((int)blockIdx.y) * 65536) + (((int)threadIdx.y) * 8192)) + (ax0 * 1024)) + (((int)blockIdx.x) * 64)) + (((int)threadIdx.x) * 8)) + ax1)] = C_local[((ax0 * 8) + ax1)];
#     }
#   }
# }
#
#
# GEMM blocking: 3035.391518 GFLOPS

# %%
def cache_read_and_coop_fetch(sch, block, nthread, read_idx, read_loc):
    read_cache = sch.cache_read(block=block, read_buffer_index=read_idx, storage_scope="shared")
    sch.compute_at(block=read_cache, loop=read_loc)
    inner0, inner1 = sch.get_loops(block=read_cache)[-2:]
    inner = sch.fuse(inner0, inner1)
    _, tx, vec = sch.split(loop=inner, factors=[None, nthread, 4])
    sch.vectorize(vec)
    sch.bind(tx, "threadIdx.x")
    
def blocking_with_shared(sch, tile_local_y, tile_local_x, tile_block_y, tile_block_x, tile_k):
    block = sch.get_block("C")
    local = sch.cache_write(block, 0, "local")
    
    i, j, k = sch.get_loops(block)
    i0, i1, i2 = sch.split(i, [None, tile_block_y, tile_local_y])
    j0, j1, j2 = sch.split(j, [None, tile_block_x, tile_local_x])
    k0, k1 = sch.split(k, [None, tile_k])
    
    sch.reorder(i0, j0, i1, j1, k0, k1, i2, j2)
    sch.reverse_compute_at(local, j1)
    
    sch.bind(i0, "blockIdx.y")
    sch.bind(j0, "blockIdx.x")
    
    tx = sch.fuse(i1, j1)
    sch.bind(tx, "threadIdx.x")
    nthread = tile_block_y * tile_block_x
    
    cache_read_and_coop_fetch(sch, block, nthread, 0, k0)
    cache_read_and_coop_fetch(sch, block, nthread, 1, k0)
    sch.decompose_reduction(block, k0)
    
    return sch

sch = tvm.tir.Schedule(MyModuleMatMul)
sch = blocking_with_shared(sch, 8, 8, 8, 8, 8)
sch.mod.show()
# Out:
# /workspace/relax/python/tvm/script/highlight.py:116: UserWarning: No module named 'black'
# To print formatted TVM script, please install the formatter 'Black':
# /opt/conda/bin/python3.8 -m pip install "black==22.3.0" --upgrade --user
#   warnings.warn(
# <div class="highlight" style="background: "><pre style="line-height: 125%;"><span></span><span style="color: #AA22FF">@tvm</span><span style="color: #AA22FF; font-weight: bold">.</span>script<span style="color: #AA22FF; font-weight: bold">.</span>ir_module
# <span style="color: #008000; font-weight: bold">class</span> <span style="color: #0000FF; font-weight: bold">Module</span>:
#     <span style="color: #AA22FF">@T</span><span style="color: #AA22FF; font-weight: bold">.</span>prim_func
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">main</span>(A: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer[(<span style="color: #008000">1024</span>, <span style="color: #008000">1024</span>), <span style="color: #BA2121">&quot;float32&quot;</span>], B: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer[(<span style="color: #008000">1024</span>, <span style="color: #008000">1024</span>), <span style="color: #BA2121">&quot;float32&quot;</span>], C: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer[(<span style="color: #008000">1024</span>, <span style="color: #008000">1024</span>), <span style="color: #BA2121">&quot;float32&quot;</span>]):
#         <span style="color: #007979; font-style: italic"># function attr dict</span>
#         T<span style="color: #AA22FF; font-weight: bold">.</span>func_attr({<span style="color: #BA2121">&quot;tir.noalias&quot;</span>: <span style="color: #008000; font-weight: bold">True</span>, <span style="color: #BA2121">&quot;global_symbol&quot;</span>: <span style="color: #BA2121">&quot;main&quot;</span>})
#         <span style="color: #007979; font-style: italic"># body</span>
#         <span style="color: #007979; font-style: italic"># with T.block(&quot;root&quot;)</span>
#         C_local <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>alloc_buffer([<span style="color: #008000">1024</span>, <span style="color: #008000">1024</span>], dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>, scope<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;local&quot;</span>)
#         A_shared <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>alloc_buffer([<span style="color: #008000">1024</span>, <span style="color: #008000">1024</span>], dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>, scope<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;shared&quot;</span>)
#         B_shared <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>alloc_buffer([<span style="color: #008000">1024</span>, <span style="color: #008000">1024</span>], dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>, scope<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;shared&quot;</span>)
#         <span style="color: #008000; font-weight: bold">for</span> i_0 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>thread_binding(<span style="color: #008000">16</span>, thread<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;blockIdx.y&quot;</span>):
#             <span style="color: #008000; font-weight: bold">for</span> j_0 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>thread_binding(<span style="color: #008000">16</span>, thread<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;blockIdx.x&quot;</span>):
#                 <span style="color: #008000; font-weight: bold">for</span> i_1_j_1_fused <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>thread_binding(<span style="color: #008000">64</span>, thread<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;threadIdx.x&quot;</span>):
#                     <span style="color: #008000; font-weight: bold">for</span> i_2_init, j_2_init <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>grid(<span style="color: #008000">8</span>, <span style="color: #008000">8</span>):
#                         <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #AA22FF; font-weight: bold">.</span>block(<span style="color: #BA2121">&quot;C_init&quot;</span>):
#                             vi <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>axis<span style="color: #AA22FF; font-weight: bold">.</span>spatial(<span style="color: #008000">1024</span>, i_0 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">64</span> <span style="color: #AA22FF; font-weight: bold">+</span> i_1_j_1_fused <span style="color: #AA22FF; font-weight: bold">//</span> <span style="color: #008000">8</span> <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">8</span> <span style="color: #AA22FF; font-weight: bold">+</span> i_2_init)
#                             vj <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>axis<span style="color: #AA22FF; font-weight: bold">.</span>spatial(<span style="color: #008000">1024</span>, j_0 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">64</span> <span style="color: #AA22FF; font-weight: bold">+</span> i_1_j_1_fused <span style="color: #AA22FF; font-weight: bold">%</span> <span style="color: #008000">8</span> <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">8</span> <span style="color: #AA22FF; font-weight: bold">+</span> j_2_init)
#                             T<span style="color: #AA22FF; font-weight: bold">.</span>reads()
#                             T<span style="color: #AA22FF; font-weight: bold">.</span>writes(C_local[vi, vj])
#                             C_local[vi, vj] <span style="color: #AA22FF; font-weight: bold">=</span> <span style="color: #008000">0</span>
#                     <span style="color: #008000; font-weight: bold">for</span> k_0 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>serial(<span style="color: #008000">128</span>):
#                         <span style="color: #008000; font-weight: bold">for</span> ax0_ax1_fused_0 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>serial(<span style="color: #008000">2</span>):
#                             <span style="color: #008000; font-weight: bold">for</span> ax0_ax1_fused_1 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>thread_binding(<span style="color: #008000">64</span>, thread<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;threadIdx.x&quot;</span>):
#                                 <span style="color: #008000; font-weight: bold">for</span> ax0_ax1_fused_2 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>vectorized(<span style="color: #008000">4</span>):
#                                     <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #AA22FF; font-weight: bold">.</span>block(<span style="color: #BA2121">&quot;A_shared&quot;</span>):
#                                         v0 <span style="color: #AA22FF; font-weight: bold">

# %%
rt_mod = tvm.build(sch.mod, target="cuda")
print(rt_mod.imported_modules[0].get_source())
evaluator = rt_mod.time_evaluator("main", tvm.cuda(0), number=10)
print("GEMM blocking shared: %f GFLOPS" %(flops / evaluator(A_nd, B_nd, C_nd).mean / 1e9))
# Out:
# #ifdef _WIN32
#   using uint = unsigned int;
#   using uchar = unsigned char;
#   using ushort = unsigned short;
#   using int64_t = long long;
#   using uint64_t = unsigned long long;
# #else
#   #define uint unsigned int
#   #define uchar unsigned char
#   #define ushort unsigned short
#   #define int64_t long long
#   #define uint64_t unsigned long long
# #endif
# extern "C" __global__ void __launch_bounds__(64) main_kernel0(float* __restrict__ A, float* __restrict__ B, float* __restrict__ C) {
#   float C_local[64];
#   __shared__ float A_shared[512];
#   __shared__ float B_shared[512];
#   for (int i_2_init = 0; i_2_init < 8; ++i_2_init) {
#     for (int j_2_init = 0; j_2_init < 8; ++j_2_init) {
#       C_local[((i_2_init * 8) + j_2_init)] = 0.000000e+00f;
#     }
#   }
#   for (int k_0 = 0; k_0 < 128; ++k_0) {
#     __syncthreads();
#     for (int ax0_ax1_fused_0 = 0; ax0_ax1_fused_0 < 2; ++ax0_ax1_fused_0) {
#       *(float4*)(A_shared + ((ax0_ax1_fused_0 * 256) + (((int)threadIdx.x) * 4))) = *(float4*)(A + (((((((int)blockIdx.y) * 65536) + (ax0_ax1_fused_0 * 32768)) + ((((int)threadIdx.x) >> 1) * 1024)) + (k_0 * 8)) + ((((int)threadIdx.x) & 1) * 4)));
#     }
#     for (int ax0_ax1_fused_0_1 = 0; ax0_ax1_fused_0_1 < 2; ++ax0_ax1_fused_0_1) {
#       *(float4*)(B_shared + ((ax0_ax1_fused_0_1 * 256) + (((int)threadIdx.x) * 4))) = *(float4*)(B + (((((k_0 * 8192) + (ax0_ax1_fused_0_1 * 4096)) + ((((int)threadIdx.x) >> 4) * 1024)) + (((int)blockIdx.x) * 64)) + ((((int)threadIdx.x) & 15) * 4)));
#     }
#     __syncthreads();
#     for (int k_1 = 0; k_1 < 8; ++k_1) {
#       for (int i_2 = 0; i_2 < 8; ++i_2) {
#         for (int j_2 = 0; j_2 < 8; ++j_2) {
#           C_local[((i_2 * 8) + j_2)] = (C_local[((i_2 * 8) + j_2)] + (A_shared[((((((int)threadIdx.x) >> 3) * 64) + (i_2 * 8)) + k_1)] * B_shared[(((k_1 * 64) + ((((int)threadIdx.x) & 7) * 8)) + j_2)]));
#         }
#       }
#     }
#   }
#   for (int ax0 = 0; ax0 < 8; ++ax0) {
#     for (int ax1 = 0; ax1 < 8; ++ax1) {
#       C[((((((((int)blockIdx.y) * 65536) + ((((int)threadIdx.x) >> 3) * 8192)) + (ax0 * 1024)) + (((int)blockIdx.x) * 64)) + ((((int)threadIdx.x) & 7) * 8)) + ax1)] = C_local[((ax0 * 8) + ax1)];
#     }
#   }
# }
#
#
# GEMM blocking shared: 4704.245086 GFLOPS

# %%
from tvm import meta_schedule as ms

sch_tuned = ms.tune_tir(mod=MyModuleMatMul,
                        target='nvidia/geforce-rtx-3060',
                        max_trials_global=64,
                        num_trials_per_iter=64,
                        work_dir='./tune_tmp',
                        task_name='main')
# Out:
# 2023-02-13 05:06:06 [INFO] [task_scheduler.cc:260] Task #0 has finished. Remaining task(s): 0
#     Name          FLOP    Weight    Speed (GFLOPS)    Latency (us)   \
# 0   main    2147483648         1         4571.5390        469.7507
#
#     Weighted Latency (us)    Trials    Done
# 0                469.7507        64       Y
# Total trials: 64
# Total latency (us): 469.751
#
# 2023-02-13 05:06:06 [DEBUG] [task_scheduler.cc:318]
#  ID | Name |       FLOP | Weight | Speed (GFLOPS) | Latency (us) | Weighted Latency (us) | Trials | Done
# ---------------------------------------------------------------------------------------------------------
#   0 | main | 2147483648 |      1 |      4571.5390 |     469.7507 |              469.7507 |     64 |    Y
# ---------------------------------------------------------------------------------------------------------
# Total trials: 64
# Total latency (us): 469.751

# %%
sch_meta_tuned = sch_tuned.query_schedule(MyModuleMatMul, target=tvm.target.Target('nvidia/geforce-rtx-3060'), workload_name='main')
sch_meta_tuned.mod.show()
# Out:
# /workspace/relax/python/tvm/script/highlight.py:116: UserWarning: No module named 'black'
# To print formatted TVM script, please install the formatter 'Black':
# /opt/conda/bin/python3.8 -m pip install "black==22.3.0" --upgrade --user
#   warnings.warn(
# <div class="highlight" style="background: "><pre style="line-height: 125%;"><span></span><span style="color: #AA22FF">@tvm</span><span style="color: #AA22FF; font-weight: bold">.</span>script<span style="color: #AA22FF; font-weight: bold">.</span>ir_module
# <span style="color: #008000; font-weight: bold">class</span> <span style="color: #0000FF; font-weight: bold">Module</span>:
#     <span style="color: #AA22FF">@T</span><span style="color: #AA22FF; font-weight: bold">.</span>prim_func
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">main</span>(A: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer[(<span style="color: #008000">1024</span>, <span style="color: #008000">1024</span>), <span style="color: #BA2121">&quot;float32&quot;</span>], B: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer[(<span style="color: #008000">1024</span>, <span style="color: #008000">1024</span>), <span style="color: #BA2121">&quot;float32&quot;</span>], C: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer[(<span style="color: #008000">1024</span>, <span style="color: #008000">1024</span>), <span style="color: #BA2121">&quot;float32&quot;</span>]):
#         <span style="color: #007979; font-style: italic"># function attr dict</span>
#         T<span style="color: #AA22FF; font-weight: bold">.</span>func_attr({<span style="color: #BA2121">&quot;global_symbol&quot;</span>: <span style="color: #BA2121">&quot;main&quot;</span>, <span style="color: #BA2121">&quot;tir.noalias&quot;</span>: <span style="color: #008000; font-weight: bold">True</span>})
#         <span style="color: #007979; font-style: italic"># body</span>
#         <span style="color: #007979; font-style: italic"># with T.block(&quot;root&quot;)</span>
#         C_local <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>alloc_buffer([<span style="color: #008000">1024</span>, <span style="color: #008000">1024</span>], dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>, scope<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;local&quot;</span>)
#         A_shared <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>alloc_buffer([<span style="color: #008000">1024</span>, <span style="color: #008000">1024</span>], dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>, scope<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;shared&quot;</span>)
#         B_shared <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>alloc_buffer([<span style="color: #008000">1024</span>, <span style="color: #008000">1024</span>], dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>, scope<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;shared&quot;</span>)
#         <span style="color: #008000; font-weight: bold">for</span> i_0_j_0_fused <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>thread_binding(<span style="color: #008000">64</span>, thread<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;blockIdx.x&quot;</span>, annotations<span style="color: #AA22FF; font-weight: bold">=</span>{<span style="color: #BA2121">&quot;pragma_auto_unroll_max_step&quot;</span>:T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">512</span>), <span style="color: #BA2121">&quot;pragma_unroll_explicit&quot;</span>:T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1</span>)}):
#             <span style="color: #008000; font-weight: bold">for</span> i_1_j_1_fused <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>thread_binding(<span style="color: #008000">4</span>, thread<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;vthread.x&quot;</span>):
#                 <span style="color: #008000; font-weight: bold">for</span> i_2_j_2_fused <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>thread_binding(<span style="color: #008000">256</span>, thread<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;threadIdx.x&quot;</span>):
#                     <span style="color: #008000; font-weight: bold">for</span> i_3_init, j_3_init, i_4_init, j_4_init <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>grid(<span style="color: #008000">4</span>, <span style="color: #008000">1</span>, <span style="color: #008000">4</span>, <span style="color: #008000">1</span>):
#                         <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #AA22FF; font-weight: bold">.</span>block(<span style="color: #BA2121">&quot;C_init&quot;</span>):
#                             vi <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>axis<span style="color: #AA22FF; font-weight: bold">.</span>spatial(<span style="color: #008000">1024</span>, i_0_j_0_fused <span style="color: #AA22FF; font-weight: bold">//</span> <span style="color: #008000">16</span> <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">256</span> <span style="color: #AA22FF; font-weight: bold">+</span> i_1_j_1_fused <span style="color: #AA22FF; font-weight: bold">//</span> <span style="color: #008000">2</span> <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">128</span> <span style="color: #AA22FF; font-weight: bold">+</span> i_2_j_2_fused <span style="color: #AA22FF; font-weight: bold">//</span> <span style="color: #008000">32</span> <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">16</span> <span style="color: #AA22FF; font-weight: bold">+</span> i_3_init <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">4</span> <span style="color: #AA22FF; font-weight: bold">+</span> i_4_init)
#                             vj <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>axis<span style="color: #AA22FF; font-weight: bold">.</span>spatial(<span style="color: #008000">1024</span>, j_4_init <span style="color: #AA22FF; font-weight: bold">+</span> i_0_j_0_fused <span style="color: #AA22FF; font-weight: bold">%</span> <span style="color: #008000">16</span> <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">64</span> <span style="color: #AA22FF; font-weight: bold">+</span> i_1_j_1_fused <span style="color: #AA22FF; font-weight: bold">%</span> <span style="color: #008000">2</span> <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">32</span> <span style="color: #AA22FF; font-weight: bold">+</span> i_2_j_2_fused <span style="color: #AA22FF; font-weight: bold">%</span> <span style="color: #008000">32</span> <span style="color: #AA22FF; font-weight: bold">+</span> j_3_init)
#                             T<span style="color: #AA22FF; font-weight: bold">.</span>reads()
#                             T<span style="color: #AA22FF; font-weight: bold">.</span>writes(C_local[vi, vj])
#                             T<span style="color: #AA22FF; font-weight: bold">.</span>block_attr({<span style="color: #BA2121">&quot;meta_schedule.thread_extent_high_inclusive&quot;</span>:T<span style="color: #

# %%
rt_mod = tvm.build(sch_meta_tuned.mod, target="nvidia/geforce-rtx-3060")
evaluator = rt_mod.time_evaluator("main", tvm.cuda(0), number=10)
print("MetaSchedule: %f GFLOPS" %(flops / evaluator(A_nd, B_nd, C_nd).mean / 1e9))
# Out:
# MetaSchedule: 4645.884922 GFLOPS

# %%
print(rt_mod.imported_modules[0].get_source())
# Out:
# #ifdef _WIN32
#   using uint = unsigned int;
#   using uchar = unsigned char;
#   using ushort = unsigned short;
#   using int64_t = long long;
#   using uint64_t = unsigned long long;
# #else
#   #define uint unsigned int
#   #define uchar unsigned char
#   #define ushort unsigned short
#   #define int64_t long long
#   #define uint64_t unsigned long long
# #endif
# extern "C" __global__ void __launch_bounds__(256) main_kernel0(float* __restrict__ A, float* __restrict__ B, float* __restrict__ C) {
#   float C_local[64];
#   __shared__ float A_shared[4096];
#   __shared__ float B_shared[1024];
#   C_local[0] = 0.000000e+00f;
#   C_local[16] = 0.000000e+00f;
#   C_local[32] = 0.000000e+00f;
#   C_local[48] = 0.000000e+00f;
#   C_local[1] = 0.000000e+00f;
#   C_local[17] = 0.000000e+00f;
#   C_local[33] = 0.000000e+00f;
#   C_local[49] = 0.000000e+00f;
#   C_local[2] = 0.000000e+00f;
#   C_local[18] = 0.000000e+00f;
#   C_local[34] = 0.000000e+00f;
#   C_local[50] = 0.000000e+00f;
#   C_local[3] = 0.000000e+00f;
#   C_local[19] = 0.000000e+00f;
#   C_local[35] = 0.000000e+00f;
#   C_local[51] = 0.000000e+00f;
#   C_local[4] = 0.000000e+00f;
#   C_local[20] = 0.000000e+00f;
#   C_local[36] = 0.000000e+00f;
#   C_local[52] = 0.000000e+00f;
#   C_local[5] = 0.000000e+00f;
#   C_local[21] = 0.000000e+00f;
#   C_local[37] = 0.000000e+00f;
#   C_local[53] = 0.000000e+00f;
#   C_local[6] = 0.000000e+00f;
#   C_local[22] = 0.000000e+00f;
#   C_local[38] = 0.000000e+00f;
#   C_local[54] = 0.000000e+00f;
#   C_local[7] = 0.000000e+00f;
#   C_local[23] = 0.000000e+00f;
#   C_local[39] = 0.000000e+00f;
#   C_local[55] = 0.000000e+00f;
#   C_local[8] = 0.000000e+00f;
#   C_local[24] = 0.000000e+00f;
#   C_local[40] = 0.000000e+00f;
#   C_local[56] = 0.000000e+00f;
#   C_local[9] = 0.000000e+00f;
#   C_local[25] = 0.000000e+00f;
#   C_local[41] = 0.000000e+00f;
#   C_local[57] = 0.000000e+00f;
#   C_local[10] = 0.000000e+00f;
#   C_local[26] = 0.000000e+00f;
#   C_local[42] = 0.000000e+00f;
#   C_local[58] = 0.000000e+00f;
#   C_local[11] = 0.000000e+00f;
#   C_local[27] = 0.000000e+00f;
#   C_local[43] = 0.000000e+00f;
#   C_local[59] = 0.000000e+00f;
#   C_local[12] = 0.000000e+00f;
#   C_local[28] = 0.000000e+00f;
#   C_local[44] = 0.000000e+00f;
#   C_local[60] = 0.000000e+00f;
#   C_local[13] = 0.000000e+00f;
#   C_local[29] = 0.000000e+00f;
#   C_local[45] = 0.000000e+00f;
#   C_local[61] = 0.000000e+00f;
#   C_local[14] = 0.000000e+00f;
#   C_local[30] = 0.000000e+00f;
#   C_local[46] = 0.000000e+00f;
#   C_local[62] = 0.000000e+00f;
#   C_local[15] = 0.000000e+00f;
#   C_local[31] = 0.000000e+00f;
#   C_local[47] = 0.000000e+00f;
#   C_local[63] = 0.000000e+00f;
#   for (int k_0 = 0; k_0 < 64; ++k_0) {
#     __syncthreads();
#     A_shared[((int)threadIdx.x)] = A[(((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 4) * 1024)) + (k_0 * 16)) + (((int)threadIdx.x) & 15))];
#     A_shared[(((int)threadIdx.x) + 256)] = A[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 4) * 1024)) + (k_0 * 16)) + (((int)threadIdx.x) & 15)) + 16384)];
#     A_shared[(((int)threadIdx.x) + 512)] = A[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 4) * 1024)) + (k_0 * 16)) + (((int)threadIdx.x) & 15)) + 32768)];
#     A_shared[(((int)threadIdx.x) + 768)] = A[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 4) * 1024)) + (k_0 * 16)) + (((int)threadIdx.x) & 15)) + 49152)];
#     A_shared[(((int)threadIdx.x) + 1024)] = A[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 4) * 1024)) + (k_0 * 16)) + (((int)threadIdx.x) & 15)) + 65536)];
#     A_shared[(((int)threadIdx.x) + 1280)] = A[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 4) * 1024)) + (k_0 * 16)) + (((int)threadIdx.x) & 15)) + 81920)];
#     A_shared[(((int)threadIdx.x) + 1536)] = A[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 4) * 1024)) + (k_0 * 16)) + (((int)threadIdx.x) & 15)) + 98304)];
#     A_shared[(((int)threadIdx.x) + 1792)] = A[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 4) * 1024)) + (k_0 * 16)) + (((int)threadIdx.x) & 15)) + 114688)];
#     A_shared[(((int)threadIdx.x) + 2048)] = A[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 4) * 1024)) + (k_0 * 16)) + (((int)threadIdx.x) & 15)) + 131072)];
#     A_shared[(((int)threadIdx.x) + 2304)] = A[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 4) * 1024)) + (k_0 * 16)) + (((int)threadIdx.x) & 15)) + 147456)];
#     A_shared[(((int)threadIdx.x) + 2560)] = A[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 4) * 1024)) + (k_0 * 16)) + (((int)threadIdx.x) & 15)) + 163840)];
#     A_shared[(((int)threadIdx.x) + 2816)] = A[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 4) * 1024)) + (k_0 * 16)) + (((int)threadIdx.x) & 15)) + 180224)];
#     A_shared[(((int)threadIdx.x) + 3072)] = A[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 4) * 1024)) + (k_0 * 16)) + (((int)threadIdx.x) & 15)) + 196608)];
#     A_shared[(((int)threadIdx.x) + 3328)] = A[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 4) * 1024)) + (k_0 * 16)) + (((int)threadIdx.x) & 15)) + 212992)];
#     A_shared[(((int)threadIdx.x) + 3584)] = A[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 4) * 1024)) + (k_0 * 16)) + (((int)threadIdx.x) & 15)) + 229376)];
#     A_shared[(((int)threadIdx.x) + 3840)] = A[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 4) * 1024)) + (k_0 * 16)) + (((int)threadIdx.x) & 15)) + 245760)];
#     B_shared[((int)threadIdx.x)] = B[((((k_0 * 16384) + ((((int)threadIdx.x) >> 6) * 1024)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 63))];
#     B_shared[(((int)threadIdx.x) + 256)] = B[(((((k_0 * 16384) + ((((int)threadIdx.x) >> 6) * 1024)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 63)) + 4096)];
#     B_shared[(((int)threadIdx.x) + 512)] = B[(((((k_0 * 16384) + ((((int)threadIdx.x) >> 6) * 1024)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 63)) + 8192)];
#     B_shared[(((int)threadIdx.x) + 768)] = B[(((((k_0 * 16384) + ((((int)threadIdx.x) >> 6) * 1024)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 63)) + 12288)];
#     __syncthreads();
#     for (int i_3 = 0; i_3 < 4; ++i_3) {
#       C_local[(i_3 * 4)] = (C_local[(i_3 * 4)] + (A_shared[(((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64))] * B_shared[(((int)threadIdx.x) & 31)]));
#       C_local[((i_3 * 4) + 16)] = (C_local[((i_3 * 4) + 16)] + (A_shared[(((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64))] * B_shared[((((int)threadIdx.x) & 31) + 32)]));
#       C_local[((i_3 * 4) + 32)] = (C_local[((i_3 * 4) + 32)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2048)] * B_shared[(((int)threadIdx.x) & 31)]));
#       C_local[((i_3 * 4) + 48)] = (C_local[((i_3 * 4) + 48)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2048)] * B_shared[((((int)threadIdx.x) & 31) + 32)]));
#       C_local[((i_3 * 4) + 1)] = (C_local[((i_3 * 4) + 1)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 16)] * B_shared[(((int)threadIdx.x) & 31)]));
#       C_local[((i_3 * 4) + 17)] = (C_local[((i_3 * 4) + 17)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 16)] * B_shared[((((int)threadIdx.x) & 31) + 32)]));
#       C_local[((i_3 * 4) + 33)] = (C_local[((i_3 * 4) + 33)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2064)] * B_shared[(((int)threadIdx.x) & 31)]));
#       C_local[((i_3 * 4) + 49)] = (C_local[((i_3 * 4) + 49)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2064)] * B_shared[((((int)threadIdx.x) & 31) + 32)]));
#       C_local[((i_3 * 4) + 2)] = (C_local[((i_3 * 4) + 2)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 32)] * B_shared[(((int)threadIdx.x) & 31)]));
#       C_local[((i_3 * 4) + 18)] = (C_local[((i_3 * 4) + 18)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 32)] * B_shared[((((int)threadIdx.x) & 31) + 32)]));
#       C_local[((i_3 * 4) + 34)] = (C_local[((i_3 * 4) + 34)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2080)] * B_shared[(((int)threadIdx.x) & 31)]));
#       C_local[((i_3 * 4) + 50)] = (C_local[((i_3 * 4) + 50)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2080)] * B_shared[((((int)threadIdx.x) & 31) + 32)]));
#       C_local[((i_3 * 4) + 3)] = (C_local[((i_3 * 4) + 3)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 48)] * B_shared[(((int)threadIdx.x) & 31)]));
#       C_local[((i_3 * 4) + 19)] = (C_local[((i_3 * 4) + 19)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 48)] * B_shared[((((int)threadIdx.x) & 31) + 32)]));
#       C_local[((i_3 * 4) + 35)] = (C_local[((i_3 * 4) + 35)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2096)] * B_shared[(((int)threadIdx.x) & 31)]));
#       C_local[((i_3 * 4) + 51)] = (C_local[((i_3 * 4) + 51)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2096)] * B_shared[((((int)threadIdx.x) & 31) + 32)]));
#       C_local[(i_3 * 4)] = (C_local[(i_3 * 4)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 1)] * B_shared[((((int)threadIdx.x) & 31) + 64)]));
#       C_local[((i_3 * 4) + 16)] = (C_local[((i_3 * 4) + 16)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 1)] * B_shared[((((int)threadIdx.x) & 31) + 96)]));
#       C_local[((i_3 * 4) + 32)] = (C_local[((i_3 * 4) + 32)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2049)] * B_shared[((((int)threadIdx.x) & 31) + 64)]));
#       C_local[((i_3 * 4) + 48)] = (C_local[((i_3 * 4) + 48)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2049)] * B_shared[((((int)threadIdx.x) & 31) + 96)]));
#       C_local[((i_3 * 4) + 1)] = (C_local[((i_3 * 4) + 1)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 17)] * B_shared[((((int)threadIdx.x) & 31) + 64)]));
#       C_local[((i_3 * 4) + 17)] = (C_local[((i_3 * 4) + 17)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 17)] * B_shared[((((int)threadIdx.x) & 31) + 96)]));
#       C_local[((i_3 * 4) + 33)] = (C_local[((i_3 * 4) + 33)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2065)] * B_shared[((((int)threadIdx.x) & 31) + 64)]));
#       C_local[((i_3 * 4) + 49)] = (C_local[((i_3 * 4) + 49)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2065)] * B_shared[((((int)threadIdx.x) & 31) + 96)]));
#       C_local[((i_3 * 4) + 2)] = (C_local[((i_3 * 4) + 2)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 33)] * B_shared[((((int)threadIdx.x) & 31) + 64)]));
#       C_local[((i_3 * 4) + 18)] = (C_local[((i_3 * 4) + 18)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 33)] * B_shared[((((int)threadIdx.x) & 31) + 96)]));
#       C_local[((i_3 * 4) + 34)] = (C_local[((i_3 * 4) + 34)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2081)] * B_shared[((((int)threadIdx.x) & 31) + 64)]));
#       C_local[((i_3 * 4) + 50)] = (C_local[((i_3 * 4) + 50)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2081)] * B_shared[((((int)threadIdx.x) & 31) + 96)]));
#       C_local[((i_3 * 4) + 3)] = (C_local[((i_3 * 4) + 3)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 49)] * B_shared[((((int)threadIdx.x) & 31) + 64)]));
#       C_local[((i_3 * 4) + 19)] = (C_local[((i_3 * 4) + 19)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 49)] * B_shared[((((int)threadIdx.x) & 31) + 96)]));
#       C_local[((i_3 * 4) + 35)] = (C_local[((i_3 * 4) + 35)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2097)] * B_shared[((((int)threadIdx.x) & 31) + 64)]));
#       C_local[((i_3 * 4) + 51)] = (C_local[((i_3 * 4) + 51)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2097)] * B_shared[((((int)threadIdx.x) & 31) + 96)]));
#       C_local[(i_3 * 4)] = (C_local[(i_3 * 4)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2)] * B_shared[((((int)threadIdx.x) & 31) + 128)]));
#       C_local[((i_3 * 4) + 16)] = (C_local[((i_3 * 4) + 16)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2)] * B_shared[((((int)threadIdx.x) & 31) + 160)]));
#       C_local[((i_3 * 4) + 32)] = (C_local[((i_3 * 4) + 32)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2050)] * B_shared[((((int)threadIdx.x) & 31) + 128)]));
#       C_local[((i_3 * 4) + 48)] = (C_local[((i_3 * 4) + 48)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2050)] * B_shared[((((int)threadIdx.x) & 31) + 160)]));
#       C_local[((i_3 * 4) + 1)] = (C_local[((i_3 * 4) + 1)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 18)] * B_shared[((((int)threadIdx.x) & 31) + 128)]));
#       C_local[((i_3 * 4) + 17)] = (C_local[((i_3 * 4) + 17)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 18)] * B_shared[((((int)threadIdx.x) & 31) + 160)]));
#       C_local[((i_3 * 4) + 33)] = (C_local[((i_3 * 4) + 33)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2066)] * B_shared[((((int)threadIdx.x) & 31) + 128)]));
#       C_local[((i_3 * 4) + 49)] = (C_local[((i_3 * 4) + 49)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2066)] * B_shared[((((int)threadIdx.x) & 31) + 160)]));
#       C_local[((i_3 * 4) + 2)] = (C_local[((i_3 * 4) + 2)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 34)] * B_shared[((((int)threadIdx.x) & 31) + 128)]));
#       C_local[((i_3 * 4) + 18)] = (C_local[((i_3 * 4) + 18)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 34)] * B_shared[((((int)threadIdx.x) & 31) + 160)]));
#       C_local[((i_3 * 4) + 34)] = (C_local[((i_3 * 4) + 34)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2082)] * B_shared[((((int)threadIdx.x) & 31) + 128)]));
#       C_local[((i_3 * 4) + 50)] = (C_local[((i_3 * 4) + 50)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2082)] * B_shared[((((int)threadIdx.x) & 31) + 160)]));
#       C_local[((i_3 * 4) + 3)] = (C_local[((i_3 * 4) + 3)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 50)] * B_shared[((((int)threadIdx.x) & 31) + 128)]));
#       C_local[((i_3 * 4) + 19)] = (C_local[((i_3 * 4) + 19)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 50)] * B_shared[((((int)threadIdx.x) & 31) + 160)]));
#       C_local[((i_3 * 4) + 35)] = (C_local[((i_3 * 4) + 35)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2098)] * B_shared[((((int)threadIdx.x) & 31) + 128)]));
#       C_local[((i_3 * 4) + 51)] = (C_local[((i_3 * 4) + 51)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2098)] * B_shared[((((int)threadIdx.x) & 31) + 160)]));
#       C_local[(i_3 * 4)] = (C_local[(i_3 * 4)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 3)] * B_shared[((((int)threadIdx.x) & 31) + 192)]));
#       C_local[((i_3 * 4) + 16)] = (C_local[((i_3 * 4) + 16)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 3)] * B_shared[((((int)threadIdx.x) & 31) + 224)]));
#       C_local[((i_3 * 4) + 32)] = (C_local[((i_3 * 4) + 32)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2051)] * B_shared[((((int)threadIdx.x) & 31) + 192)]));
#       C_local[((i_3 * 4) + 48)] = (C_local[((i_3 * 4) + 48)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2051)] * B_shared[((((int)threadIdx.x) & 31) + 224)]));
#       C_local[((i_3 * 4) + 1)] = (C_local[((i_3 * 4) + 1)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 19)] * B_shared[((((int)threadIdx.x) & 31) + 192)]));
#       C_local[((i_3 * 4) + 17)] = (C_local[((i_3 * 4) + 17)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 19)] * B_shared[((((int)threadIdx.x) & 31) + 224)]));
#       C_local[((i_3 * 4) + 33)] = (C_local[((i_3 * 4) + 33)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2067)] * B_shared[((((int)threadIdx.x) & 31) + 192)]));
#       C_local[((i_3 * 4) + 49)] = (C_local[((i_3 * 4) + 49)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2067)] * B_shared[((((int)threadIdx.x) & 31) + 224)]));
#       C_local[((i_3 * 4) + 2)] = (C_local[((i_3 * 4) + 2)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 35)] * B_shared[((((int)threadIdx.x) & 31) + 192)]));
#       C_local[((i_3 * 4) + 18)] = (C_local[((i_3 * 4) + 18)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 35)] * B_shared[((((int)threadIdx.x) & 31) + 224)]));
#       C_local[((i_3 * 4) + 34)] = (C_local[((i_3 * 4) + 34)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2083)] * B_shared[((((int)threadIdx.x) & 31) + 192)]));
#       C_local[((i_3 * 4) + 50)] = (C_local[((i_3 * 4) + 50)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2083)] * B_shared[((((int)threadIdx.x) & 31) + 224)]));
#       C_local[((i_3 * 4) + 3)] = (C_local[((i_3 * 4) + 3)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 51)] * B_shared[((((int)threadIdx.x) & 31) + 192)]));
#       C_local[((i_3 * 4) + 19)] = (C_local[((i_3 * 4) + 19)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 51)] * B_shared[((((int)threadIdx.x) & 31) + 224)]));
#       C_local[((i_3 * 4) + 35)] = (C_local[((i_3 * 4) + 35)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2099)] * B_shared[((((int)threadIdx.x) & 31) + 192)]));
#       C_local[((i_3 * 4) + 51)] = (C_local[((i_3 * 4) + 51)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2099)] * B_shared[((((int)threadIdx.x) & 31) + 224)]));
#       C_local[(i_3 * 4)] = (C_local[(i_3 * 4)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 4)] * B_shared[((((int)threadIdx.x) & 31) + 256)]));
#       C_local[((i_3 * 4) + 16)] = (C_local[((i_3 * 4) + 16)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 4)] * B_shared[((((int)threadIdx.x) & 31) + 288)]));
#       C_local[((i_3 * 4) + 32)] = (C_local[((i_3 * 4) + 32)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2052)] * B_shared[((((int)threadIdx.x) & 31) + 256)]));
#       C_local[((i_3 * 4) + 48)] = (C_local[((i_3 * 4) + 48)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2052)] * B_shared[((((int)threadIdx.x) & 31) + 288)]));
#       C_local[((i_3 * 4) + 1)] = (C_local[((i_3 * 4) + 1)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 20)] * B_shared[((((int)threadIdx.x) & 31) + 256)]));
#       C_local[((i_3 * 4) + 17)] = (C_local[((i_3 * 4) + 17)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 20)] * B_shared[((((int)threadIdx.x) & 31) + 288)]));
#       C_local[((i_3 * 4) + 33)] = (C_local[((i_3 * 4) + 33)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2068)] * B_shared[((((int)threadIdx.x) & 31) + 256)]));
#       C_local[((i_3 * 4) + 49)] = (C_local[((i_3 * 4) + 49)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2068)] * B_shared[((((int)threadIdx.x) & 31) + 288)]));
#       C_local[((i_3 * 4) + 2)] = (C_local[((i_3 * 4) + 2)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 36)] * B_shared[((((int)threadIdx.x) & 31) + 256)]));
#       C_local[((i_3 * 4) + 18)] = (C_local[((i_3 * 4) + 18)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 36)] * B_shared[((((int)threadIdx.x) & 31) + 288)]));
#       C_local[((i_3 * 4) + 34)] = (C_local[((i_3 * 4) + 34)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2084)] * B_shared[((((int)threadIdx.x) & 31) + 256)]));
#       C_local[((i_3 * 4) + 50)] = (C_local[((i_3 * 4) + 50)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2084)] * B_shared[((((int)threadIdx.x) & 31) + 288)]));
#       C_local[((i_3 * 4) + 3)] = (C_local[((i_3 * 4) + 3)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 52)] * B_shared[((((int)threadIdx.x) & 31) + 256)]));
#       C_local[((i_3 * 4) + 19)] = (C_local[((i_3 * 4) + 19)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 52)] * B_shared[((((int)threadIdx.x) & 31) + 288)]));
#       C_local[((i_3 * 4) + 35)] = (C_local[((i_3 * 4) + 35)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2100)] * B_shared[((((int)threadIdx.x) & 31) + 256)]));
#       C_local[((i_3 * 4) + 51)] = (C_local[((i_3 * 4) + 51)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2100)] * B_shared[((((int)threadIdx.x) & 31) + 288)]));
#       C_local[(i_3 * 4)] = (C_local[(i_3 * 4)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 5)] * B_shared[((((int)threadIdx.x) & 31) + 320)]));
#       C_local[((i_3 * 4) + 16)] = (C_local[((i_3 * 4) + 16)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 5)] * B_shared[((((int)threadIdx.x) & 31) + 352)]));
#       C_local[((i_3 * 4) + 32)] = (C_local[((i_3 * 4) + 32)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2053)] * B_shared[((((int)threadIdx.x) & 31) + 320)]));
#       C_local[((i_3 * 4) + 48)] = (C_local[((i_3 * 4) + 48)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2053)] * B_shared[((((int)threadIdx.x) & 31) + 352)]));
#       C_local[((i_3 * 4) + 1)] = (C_local[((i_3 * 4) + 1)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 21)] * B_shared[((((int)threadIdx.x) & 31) + 320)]));
#       C_local[((i_3 * 4) + 17)] = (C_local[((i_3 * 4) + 17)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 21)] * B_shared[((((int)threadIdx.x) & 31) + 352)]));
#       C_local[((i_3 * 4) + 33)] = (C_local[((i_3 * 4) + 33)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2069)] * B_shared[((((int)threadIdx.x) & 31) + 320)]));
#       C_local[((i_3 * 4) + 49)] = (C_local[((i_3 * 4) + 49)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2069)] * B_shared[((((int)threadIdx.x) & 31) + 352)]));
#       C_local[((i_3 * 4) + 2)] = (C_local[((i_3 * 4) + 2)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 37)] * B_shared[((((int)threadIdx.x) & 31) + 320)]));
#       C_local[((i_3 * 4) + 18)] = (C_local[((i_3 * 4) + 18)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 37)] * B_shared[((((int)threadIdx.x) & 31) + 352)]));
#       C_local[((i_3 * 4) + 34)] = (C_local[((i_3 * 4) + 34)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2085)] * B_shared[((((int)threadIdx.x) & 31) + 320)]));
#       C_local[((i_3 * 4) + 50)] = (C_local[((i_3 * 4) + 50)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2085)] * B_shared[((((int)threadIdx.x) & 31) + 352)]));
#       C_local[((i_3 * 4) + 3)] = (C_local[((i_3 * 4) + 3)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 53)] * B_shared[((((int)threadIdx.x) & 31) + 320)]));
#       C_local[((i_3 * 4) + 19)] = (C_local[((i_3 * 4) + 19)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 53)] * B_shared[((((int)threadIdx.x) & 31) + 352)]));
#       C_local[((i_3 * 4) + 35)] = (C_local[((i_3 * 4) + 35)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2101)] * B_shared[((((int)threadIdx.x) & 31) + 320)]));
#       C_local[((i_3 * 4) + 51)] = (C_local[((i_3 * 4) + 51)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2101)] * B_shared[((((int)threadIdx.x) & 31) + 352)]));
#       C_local[(i_3 * 4)] = (C_local[(i_3 * 4)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 6)] * B_shared[((((int)threadIdx.x) & 31) + 384)]));
#       C_local[((i_3 * 4) + 16)] = (C_local[((i_3 * 4) + 16)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 6)] * B_shared[((((int)threadIdx.x) & 31) + 416)]));
#       C_local[((i_3 * 4) + 32)] = (C_local[((i_3 * 4) + 32)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2054)] * B_shared[((((int)threadIdx.x) & 31) + 384)]));
#       C_local[((i_3 * 4) + 48)] = (C_local[((i_3 * 4) + 48)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2054)] * B_shared[((((int)threadIdx.x) & 31) + 416)]));
#       C_local[((i_3 * 4) + 1)] = (C_local[((i_3 * 4) + 1)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 22)] * B_shared[((((int)threadIdx.x) & 31) + 384)]));
#       C_local[((i_3 * 4) + 17)] = (C_local[((i_3 * 4) + 17)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 22)] * B_shared[((((int)threadIdx.x) & 31) + 416)]));
#       C_local[((i_3 * 4) + 33)] = (C_local[((i_3 * 4) + 33)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2070)] * B_shared[((((int)threadIdx.x) & 31) + 384)]));
#       C_local[((i_3 * 4) + 49)] = (C_local[((i_3 * 4) + 49)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2070)] * B_shared[((((int)threadIdx.x) & 31) + 416)]));
#       C_local[((i_3 * 4) + 2)] = (C_local[((i_3 * 4) + 2)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 38)] * B_shared[((((int)threadIdx.x) & 31) + 384)]));
#       C_local[((i_3 * 4) + 18)] = (C_local[((i_3 * 4) + 18)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 38)] * B_shared[((((int)threadIdx.x) & 31) + 416)]));
#       C_local[((i_3 * 4) + 34)] = (C_local[((i_3 * 4) + 34)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2086)] * B_shared[((((int)threadIdx.x) & 31) + 384)]));
#       C_local[((i_3 * 4) + 50)] = (C_local[((i_3 * 4) + 50)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2086)] * B_shared[((((int)threadIdx.x) & 31) + 416)]));
#       C_local[((i_3 * 4) + 3)] = (C_local[((i_3 * 4) + 3)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 54)] * B_shared[((((int)threadIdx.x) & 31) + 384)]));
#       C_local[((i_3 * 4) + 19)] = (C_local[((i_3 * 4) + 19)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 54)] * B_shared[((((int)threadIdx.x) & 31) + 416)]));
#       C_local[((i_3 * 4) + 35)] = (C_local[((i_3 * 4) + 35)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2102)] * B_shared[((((int)threadIdx.x) & 31) + 384)]));
#       C_local[((i_3 * 4) + 51)] = (C_local[((i_3 * 4) + 51)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2102)] * B_shared[((((int)threadIdx.x) & 31) + 416)]));
#       C_local[(i_3 * 4)] = (C_local[(i_3 * 4)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 7)] * B_shared[((((int)threadIdx.x) & 31) + 448)]));
#       C_local[((i_3 * 4) + 16)] = (C_local[((i_3 * 4) + 16)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 7)] * B_shared[((((int)threadIdx.x) & 31) + 480)]));
#       C_local[((i_3 * 4) + 32)] = (C_local[((i_3 * 4) + 32)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2055)] * B_shared[((((int)threadIdx.x) & 31) + 448)]));
#       C_local[((i_3 * 4) + 48)] = (C_local[((i_3 * 4) + 48)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2055)] * B_shared[((((int)threadIdx.x) & 31) + 480)]));
#       C_local[((i_3 * 4) + 1)] = (C_local[((i_3 * 4) + 1)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 23)] * B_shared[((((int)threadIdx.x) & 31) + 448)]));
#       C_local[((i_3 * 4) + 17)] = (C_local[((i_3 * 4) + 17)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 23)] * B_shared[((((int)threadIdx.x) & 31) + 480)]));
#       C_local[((i_3 * 4) + 33)] = (C_local[((i_3 * 4) + 33)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2071)] * B_shared[((((int)threadIdx.x) & 31) + 448)]));
#       C_local[((i_3 * 4) + 49)] = (C_local[((i_3 * 4) + 49)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2071)] * B_shared[((((int)threadIdx.x) & 31) + 480)]));
#       C_local[((i_3 * 4) + 2)] = (C_local[((i_3 * 4) + 2)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 39)] * B_shared[((((int)threadIdx.x) & 31) + 448)]));
#       C_local[((i_3 * 4) + 18)] = (C_local[((i_3 * 4) + 18)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 39)] * B_shared[((((int)threadIdx.x) & 31) + 480)]));
#       C_local[((i_3 * 4) + 34)] = (C_local[((i_3 * 4) + 34)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2087)] * B_shared[((((int)threadIdx.x) & 31) + 448)]));
#       C_local[((i_3 * 4) + 50)] = (C_local[((i_3 * 4) + 50)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2087)] * B_shared[((((int)threadIdx.x) & 31) + 480)]));
#       C_local[((i_3 * 4) + 3)] = (C_local[((i_3 * 4) + 3)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 55)] * B_shared[((((int)threadIdx.x) & 31) + 448)]));
#       C_local[((i_3 * 4) + 19)] = (C_local[((i_3 * 4) + 19)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 55)] * B_shared[((((int)threadIdx.x) & 31) + 480)]));
#       C_local[((i_3 * 4) + 35)] = (C_local[((i_3 * 4) + 35)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2103)] * B_shared[((((int)threadIdx.x) & 31) + 448)]));
#       C_local[((i_3 * 4) + 51)] = (C_local[((i_3 * 4) + 51)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2103)] * B_shared[((((int)threadIdx.x) & 31) + 480)]));
#       C_local[(i_3 * 4)] = (C_local[(i_3 * 4)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 8)] * B_shared[((((int)threadIdx.x) & 31) + 512)]));
#       C_local[((i_3 * 4) + 16)] = (C_local[((i_3 * 4) + 16)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 8)] * B_shared[((((int)threadIdx.x) & 31) + 544)]));
#       C_local[((i_3 * 4) + 32)] = (C_local[((i_3 * 4) + 32)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2056)] * B_shared[((((int)threadIdx.x) & 31) + 512)]));
#       C_local[((i_3 * 4) + 48)] = (C_local[((i_3 * 4) + 48)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2056)] * B_shared[((((int)threadIdx.x) & 31) + 544)]));
#       C_local[((i_3 * 4) + 1)] = (C_local[((i_3 * 4) + 1)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 24)] * B_shared[((((int)threadIdx.x) & 31) + 512)]));
#       C_local[((i_3 * 4) + 17)] = (C_local[((i_3 * 4) + 17)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 24)] * B_shared[((((int)threadIdx.x) & 31) + 544)]));
#       C_local[((i_3 * 4) + 33)] = (C_local[((i_3 * 4) + 33)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2072)] * B_shared[((((int)threadIdx.x) & 31) + 512)]));
#       C_local[((i_3 * 4) + 49)] = (C_local[((i_3 * 4) + 49)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2072)] * B_shared[((((int)threadIdx.x) & 31) + 544)]));
#       C_local[((i_3 * 4) + 2)] = (C_local[((i_3 * 4) + 2)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 40)] * B_shared[((((int)threadIdx.x) & 31) + 512)]));
#       C_local[((i_3 * 4) + 18)] = (C_local[((i_3 * 4) + 18)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 40)] * B_shared[((((int)threadIdx.x) & 31) + 544)]));
#       C_local[((i_3 * 4) + 34)] = (C_local[((i_3 * 4) + 34)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2088)] * B_shared[((((int)threadIdx.x) & 31) + 512)]));
#       C_local[((i_3 * 4) + 50)] = (C_local[((i_3 * 4) + 50)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2088)] * B_shared[((((int)threadIdx.x) & 31) + 544)]));
#       C_local[((i_3 * 4) + 3)] = (C_local[((i_3 * 4) + 3)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 56)] * B_shared[((((int)threadIdx.x) & 31) + 512)]));
#       C_local[((i_3 * 4) + 19)] = (C_local[((i_3 * 4) + 19)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 56)] * B_shared[((((int)threadIdx.x) & 31) + 544)]));
#       C_local[((i_3 * 4) + 35)] = (C_local[((i_3 * 4) + 35)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2104)] * B_shared[((((int)threadIdx.x) & 31) + 512)]));
#       C_local[((i_3 * 4) + 51)] = (C_local[((i_3 * 4) + 51)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2104)] * B_shared[((((int)threadIdx.x) & 31) + 544)]));
#       C_local[(i_3 * 4)] = (C_local[(i_3 * 4)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 9)] * B_shared[((((int)threadIdx.x) & 31) + 576)]));
#       C_local[((i_3 * 4) + 16)] = (C_local[((i_3 * 4) + 16)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 9)] * B_shared[((((int)threadIdx.x) & 31) + 608)]));
#       C_local[((i_3 * 4) + 32)] = (C_local[((i_3 * 4) + 32)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2057)] * B_shared[((((int)threadIdx.x) & 31) + 576)]));
#       C_local[((i_3 * 4) + 48)] = (C_local[((i_3 * 4) + 48)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2057)] * B_shared[((((int)threadIdx.x) & 31) + 608)]));
#       C_local[((i_3 * 4) + 1)] = (C_local[((i_3 * 4) + 1)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 25)] * B_shared[((((int)threadIdx.x) & 31) + 576)]));
#       C_local[((i_3 * 4) + 17)] = (C_local[((i_3 * 4) + 17)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 25)] * B_shared[((((int)threadIdx.x) & 31) + 608)]));
#       C_local[((i_3 * 4) + 33)] = (C_local[((i_3 * 4) + 33)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2073)] * B_shared[((((int)threadIdx.x) & 31) + 576)]));
#       C_local[((i_3 * 4) + 49)] = (C_local[((i_3 * 4) + 49)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2073)] * B_shared[((((int)threadIdx.x) & 31) + 608)]));
#       C_local[((i_3 * 4) + 2)] = (C_local[((i_3 * 4) + 2)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 41)] * B_shared[((((int)threadIdx.x) & 31) + 576)]));
#       C_local[((i_3 * 4) + 18)] = (C_local[((i_3 * 4) + 18)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 41)] * B_shared[((((int)threadIdx.x) & 31) + 608)]));
#       C_local[((i_3 * 4) + 34)] = (C_local[((i_3 * 4) + 34)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2089)] * B_shared[((((int)threadIdx.x) & 31) + 576)]));
#       C_local[((i_3 * 4) + 50)] = (C_local[((i_3 * 4) + 50)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2089)] * B_shared[((((int)threadIdx.x) & 31) + 608)]));
#       C_local[((i_3 * 4) + 3)] = (C_local[((i_3 * 4) + 3)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 57)] * B_shared[((((int)threadIdx.x) & 31) + 576)]));
#       C_local[((i_3 * 4) + 19)] = (C_local[((i_3 * 4) + 19)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 57)] * B_shared[((((int)threadIdx.x) & 31) + 608)]));
#       C_local[((i_3 * 4) + 35)] = (C_local[((i_3 * 4) + 35)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2105)] * B_shared[((((int)threadIdx.x) & 31) + 576)]));
#       C_local[((i_3 * 4) + 51)] = (C_local[((i_3 * 4) + 51)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2105)] * B_shared[((((int)threadIdx.x) & 31) + 608)]));
#       C_local[(i_3 * 4)] = (C_local[(i_3 * 4)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 10)] * B_shared[((((int)threadIdx.x) & 31) + 640)]));
#       C_local[((i_3 * 4) + 16)] = (C_local[((i_3 * 4) + 16)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 10)] * B_shared[((((int)threadIdx.x) & 31) + 672)]));
#       C_local[((i_3 * 4) + 32)] = (C_local[((i_3 * 4) + 32)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2058)] * B_shared[((((int)threadIdx.x) & 31) + 640)]));
#       C_local[((i_3 * 4) + 48)] = (C_local[((i_3 * 4) + 48)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2058)] * B_shared[((((int)threadIdx.x) & 31) + 672)]));
#       C_local[((i_3 * 4) + 1)] = (C_local[((i_3 * 4) + 1)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 26)] * B_shared[((((int)threadIdx.x) & 31) + 640)]));
#       C_local[((i_3 * 4) + 17)] = (C_local[((i_3 * 4) + 17)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 26)] * B_shared[((((int)threadIdx.x) & 31) + 672)]));
#       C_local[((i_3 * 4) + 33)] = (C_local[((i_3 * 4) + 33)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2074)] * B_shared[((((int)threadIdx.x) & 31) + 640)]));
#       C_local[((i_3 * 4) + 49)] = (C_local[((i_3 * 4) + 49)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2074)] * B_shared[((((int)threadIdx.x) & 31) + 672)]));
#       C_local[((i_3 * 4) + 2)] = (C_local[((i_3 * 4) + 2)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 42)] * B_shared[((((int)threadIdx.x) & 31) + 640)]));
#       C_local[((i_3 * 4) + 18)] = (C_local[((i_3 * 4) + 18)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 42)] * B_shared[((((int)threadIdx.x) & 31) + 672)]));
#       C_local[((i_3 * 4) + 34)] = (C_local[((i_3 * 4) + 34)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2090)] * B_shared[((((int)threadIdx.x) & 31) + 640)]));
#       C_local[((i_3 * 4) + 50)] = (C_local[((i_3 * 4) + 50)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2090)] * B_shared[((((int)threadIdx.x) & 31) + 672)]));
#       C_local[((i_3 * 4) + 3)] = (C_local[((i_3 * 4) + 3)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 58)] * B_shared[((((int)threadIdx.x) & 31) + 640)]));
#       C_local[((i_3 * 4) + 19)] = (C_local[((i_3 * 4) + 19)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 58)] * B_shared[((((int)threadIdx.x) & 31) + 672)]));
#       C_local[((i_3 * 4) + 35)] = (C_local[((i_3 * 4) + 35)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2106)] * B_shared[((((int)threadIdx.x) & 31) + 640)]));
#       C_local[((i_3 * 4) + 51)] = (C_local[((i_3 * 4) + 51)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2106)] * B_shared[((((int)threadIdx.x) & 31) + 672)]));
#       C_local[(i_3 * 4)] = (C_local[(i_3 * 4)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 11)] * B_shared[((((int)threadIdx.x) & 31) + 704)]));
#       C_local[((i_3 * 4) + 16)] = (C_local[((i_3 * 4) + 16)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 11)] * B_shared[((((int)threadIdx.x) & 31) + 736)]));
#       C_local[((i_3 * 4) + 32)] = (C_local[((i_3 * 4) + 32)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2059)] * B_shared[((((int)threadIdx.x) & 31) + 704)]));
#       C_local[((i_3 * 4) + 48)] = (C_local[((i_3 * 4) + 48)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2059)] * B_shared[((((int)threadIdx.x) & 31) + 736)]));
#       C_local[((i_3 * 4) + 1)] = (C_local[((i_3 * 4) + 1)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 27)] * B_shared[((((int)threadIdx.x) & 31) + 704)]));
#       C_local[((i_3 * 4) + 17)] = (C_local[((i_3 * 4) + 17)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 27)] * B_shared[((((int)threadIdx.x) & 31) + 736)]));
#       C_local[((i_3 * 4) + 33)] = (C_local[((i_3 * 4) + 33)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2075)] * B_shared[((((int)threadIdx.x) & 31) + 704)]));
#       C_local[((i_3 * 4) + 49)] = (C_local[((i_3 * 4) + 49)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2075)] * B_shared[((((int)threadIdx.x) & 31) + 736)]));
#       C_local[((i_3 * 4) + 2)] = (C_local[((i_3 * 4) + 2)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 43)] * B_shared[((((int)threadIdx.x) & 31) + 704)]));
#       C_local[((i_3 * 4) + 18)] = (C_local[((i_3 * 4) + 18)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 43)] * B_shared[((((int)threadIdx.x) & 31) + 736)]));
#       C_local[((i_3 * 4) + 34)] = (C_local[((i_3 * 4) + 34)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2091)] * B_shared[((((int)threadIdx.x) & 31) + 704)]));
#       C_local[((i_3 * 4) + 50)] = (C_local[((i_3 * 4) + 50)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2091)] * B_shared[((((int)threadIdx.x) & 31) + 736)]));
#       C_local[((i_3 * 4) + 3)] = (C_local[((i_3 * 4) + 3)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 59)] * B_shared[((((int)threadIdx.x) & 31) + 704)]));
#       C_local[((i_3 * 4) + 19)] = (C_local[((i_3 * 4) + 19)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 59)] * B_shared[((((int)threadIdx.x) & 31) + 736)]));
#       C_local[((i_3 * 4) + 35)] = (C_local[((i_3 * 4) + 35)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2107)] * B_shared[((((int)threadIdx.x) & 31) + 704)]));
#       C_local[((i_3 * 4) + 51)] = (C_local[((i_3 * 4) + 51)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2107)] * B_shared[((((int)threadIdx.x) & 31) + 736)]));
#       C_local[(i_3 * 4)] = (C_local[(i_3 * 4)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 12)] * B_shared[((((int)threadIdx.x) & 31) + 768)]));
#       C_local[((i_3 * 4) + 16)] = (C_local[((i_3 * 4) + 16)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 12)] * B_shared[((((int)threadIdx.x) & 31) + 800)]));
#       C_local[((i_3 * 4) + 32)] = (C_local[((i_3 * 4) + 32)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2060)] * B_shared[((((int)threadIdx.x) & 31) + 768)]));
#       C_local[((i_3 * 4) + 48)] = (C_local[((i_3 * 4) + 48)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2060)] * B_shared[((((int)threadIdx.x) & 31) + 800)]));
#       C_local[((i_3 * 4) + 1)] = (C_local[((i_3 * 4) + 1)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 28)] * B_shared[((((int)threadIdx.x) & 31) + 768)]));
#       C_local[((i_3 * 4) + 17)] = (C_local[((i_3 * 4) + 17)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 28)] * B_shared[((((int)threadIdx.x) & 31) + 800)]));
#       C_local[((i_3 * 4) + 33)] = (C_local[((i_3 * 4) + 33)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2076)] * B_shared[((((int)threadIdx.x) & 31) + 768)]));
#       C_local[((i_3 * 4) + 49)] = (C_local[((i_3 * 4) + 49)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2076)] * B_shared[((((int)threadIdx.x) & 31) + 800)]));
#       C_local[((i_3 * 4) + 2)] = (C_local[((i_3 * 4) + 2)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 44)] * B_shared[((((int)threadIdx.x) & 31) + 768)]));
#       C_local[((i_3 * 4) + 18)] = (C_local[((i_3 * 4) + 18)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 44)] * B_shared[((((int)threadIdx.x) & 31) + 800)]));
#       C_local[((i_3 * 4) + 34)] = (C_local[((i_3 * 4) + 34)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2092)] * B_shared[((((int)threadIdx.x) & 31) + 768)]));
#       C_local[((i_3 * 4) + 50)] = (C_local[((i_3 * 4) + 50)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2092)] * B_shared[((((int)threadIdx.x) & 31) + 800)]));
#       C_local[((i_3 * 4) + 3)] = (C_local[((i_3 * 4) + 3)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 60)] * B_shared[((((int)threadIdx.x) & 31) + 768)]));
#       C_local[((i_3 * 4) + 19)] = (C_local[((i_3 * 4) + 19)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 60)] * B_shared[((((int)threadIdx.x) & 31) + 800)]));
#       C_local[((i_3 * 4) + 35)] = (C_local[((i_3 * 4) + 35)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2108)] * B_shared[((((int)threadIdx.x) & 31) + 768)]));
#       C_local[((i_3 * 4) + 51)] = (C_local[((i_3 * 4) + 51)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2108)] * B_shared[((((int)threadIdx.x) & 31) + 800)]));
#       C_local[(i_3 * 4)] = (C_local[(i_3 * 4)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 13)] * B_shared[((((int)threadIdx.x) & 31) + 832)]));
#       C_local[((i_3 * 4) + 16)] = (C_local[((i_3 * 4) + 16)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 13)] * B_shared[((((int)threadIdx.x) & 31) + 864)]));
#       C_local[((i_3 * 4) + 32)] = (C_local[((i_3 * 4) + 32)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2061)] * B_shared[((((int)threadIdx.x) & 31) + 832)]));
#       C_local[((i_3 * 4) + 48)] = (C_local[((i_3 * 4) + 48)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2061)] * B_shared[((((int)threadIdx.x) & 31) + 864)]));
#       C_local[((i_3 * 4) + 1)] = (C_local[((i_3 * 4) + 1)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 29)] * B_shared[((((int)threadIdx.x) & 31) + 832)]));
#       C_local[((i_3 * 4) + 17)] = (C_local[((i_3 * 4) + 17)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 29)] * B_shared[((((int)threadIdx.x) & 31) + 864)]));
#       C_local[((i_3 * 4) + 33)] = (C_local[((i_3 * 4) + 33)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2077)] * B_shared[((((int)threadIdx.x) & 31) + 832)]));
#       C_local[((i_3 * 4) + 49)] = (C_local[((i_3 * 4) + 49)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2077)] * B_shared[((((int)threadIdx.x) & 31) + 864)]));
#       C_local[((i_3 * 4) + 2)] = (C_local[((i_3 * 4) + 2)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 45)] * B_shared[((((int)threadIdx.x) & 31) + 832)]));
#       C_local[((i_3 * 4) + 18)] = (C_local[((i_3 * 4) + 18)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 45)] * B_shared[((((int)threadIdx.x) & 31) + 864)]));
#       C_local[((i_3 * 4) + 34)] = (C_local[((i_3 * 4) + 34)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2093)] * B_shared[((((int)threadIdx.x) & 31) + 832)]));
#       C_local[((i_3 * 4) + 50)] = (C_local[((i_3 * 4) + 50)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2093)] * B_shared[((((int)threadIdx.x) & 31) + 864)]));
#       C_local[((i_3 * 4) + 3)] = (C_local[((i_3 * 4) + 3)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 61)] * B_shared[((((int)threadIdx.x) & 31) + 832)]));
#       C_local[((i_3 * 4) + 19)] = (C_local[((i_3 * 4) + 19)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 61)] * B_shared[((((int)threadIdx.x) & 31) + 864)]));
#       C_local[((i_3 * 4) + 35)] = (C_local[((i_3 * 4) + 35)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2109)] * B_shared[((((int)threadIdx.x) & 31) + 832)]));
#       C_local[((i_3 * 4) + 51)] = (C_local[((i_3 * 4) + 51)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2109)] * B_shared[((((int)threadIdx.x) & 31) + 864)]));
#       C_local[(i_3 * 4)] = (C_local[(i_3 * 4)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 14)] * B_shared[((((int)threadIdx.x) & 31) + 896)]));
#       C_local[((i_3 * 4) + 16)] = (C_local[((i_3 * 4) + 16)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 14)] * B_shared[((((int)threadIdx.x) & 31) + 928)]));
#       C_local[((i_3 * 4) + 32)] = (C_local[((i_3 * 4) + 32)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2062)] * B_shared[((((int)threadIdx.x) & 31) + 896)]));
#       C_local[((i_3 * 4) + 48)] = (C_local[((i_3 * 4) + 48)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2062)] * B_shared[((((int)threadIdx.x) & 31) + 928)]));
#       C_local[((i_3 * 4) + 1)] = (C_local[((i_3 * 4) + 1)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 30)] * B_shared[((((int)threadIdx.x) & 31) + 896)]));
#       C_local[((i_3 * 4) + 17)] = (C_local[((i_3 * 4) + 17)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 30)] * B_shared[((((int)threadIdx.x) & 31) + 928)]));
#       C_local[((i_3 * 4) + 33)] = (C_local[((i_3 * 4) + 33)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2078)] * B_shared[((((int)threadIdx.x) & 31) + 896)]));
#       C_local[((i_3 * 4) + 49)] = (C_local[((i_3 * 4) + 49)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2078)] * B_shared[((((int)threadIdx.x) & 31) + 928)]));
#       C_local[((i_3 * 4) + 2)] = (C_local[((i_3 * 4) + 2)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 46)] * B_shared[((((int)threadIdx.x) & 31) + 896)]));
#       C_local[((i_3 * 4) + 18)] = (C_local[((i_3 * 4) + 18)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 46)] * B_shared[((((int)threadIdx.x) & 31) + 928)]));
#       C_local[((i_3 * 4) + 34)] = (C_local[((i_3 * 4) + 34)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2094)] * B_shared[((((int)threadIdx.x) & 31) + 896)]));
#       C_local[((i_3 * 4) + 50)] = (C_local[((i_3 * 4) + 50)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2094)] * B_shared[((((int)threadIdx.x) & 31) + 928)]));
#       C_local[((i_3 * 4) + 3)] = (C_local[((i_3 * 4) + 3)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 62)] * B_shared[((((int)threadIdx.x) & 31) + 896)]));
#       C_local[((i_3 * 4) + 19)] = (C_local[((i_3 * 4) + 19)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 62)] * B_shared[((((int)threadIdx.x) & 31) + 928)]));
#       C_local[((i_3 * 4) + 35)] = (C_local[((i_3 * 4) + 35)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2110)] * B_shared[((((int)threadIdx.x) & 31) + 896)]));
#       C_local[((i_3 * 4) + 51)] = (C_local[((i_3 * 4) + 51)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2110)] * B_shared[((((int)threadIdx.x) & 31) + 928)]));
#       C_local[(i_3 * 4)] = (C_local[(i_3 * 4)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 15)] * B_shared[((((int)threadIdx.x) & 31) + 960)]));
#       C_local[((i_3 * 4) + 16)] = (C_local[((i_3 * 4) + 16)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 15)] * B_shared[((((int)threadIdx.x) & 31) + 992)]));
#       C_local[((i_3 * 4) + 32)] = (C_local[((i_3 * 4) + 32)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2063)] * B_shared[((((int)threadIdx.x) & 31) + 960)]));
#       C_local[((i_3 * 4) + 48)] = (C_local[((i_3 * 4) + 48)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2063)] * B_shared[((((int)threadIdx.x) & 31) + 992)]));
#       C_local[((i_3 * 4) + 1)] = (C_local[((i_3 * 4) + 1)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 31)] * B_shared[((((int)threadIdx.x) & 31) + 960)]));
#       C_local[((i_3 * 4) + 17)] = (C_local[((i_3 * 4) + 17)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 31)] * B_shared[((((int)threadIdx.x) & 31) + 992)]));
#       C_local[((i_3 * 4) + 33)] = (C_local[((i_3 * 4) + 33)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2079)] * B_shared[((((int)threadIdx.x) & 31) + 960)]));
#       C_local[((i_3 * 4) + 49)] = (C_local[((i_3 * 4) + 49)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2079)] * B_shared[((((int)threadIdx.x) & 31) + 992)]));
#       C_local[((i_3 * 4) + 2)] = (C_local[((i_3 * 4) + 2)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 47)] * B_shared[((((int)threadIdx.x) & 31) + 960)]));
#       C_local[((i_3 * 4) + 18)] = (C_local[((i_3 * 4) + 18)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 47)] * B_shared[((((int)threadIdx.x) & 31) + 992)]));
#       C_local[((i_3 * 4) + 34)] = (C_local[((i_3 * 4) + 34)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2095)] * B_shared[((((int)threadIdx.x) & 31) + 960)]));
#       C_local[((i_3 * 4) + 50)] = (C_local[((i_3 * 4) + 50)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2095)] * B_shared[((((int)threadIdx.x) & 31) + 992)]));
#       C_local[((i_3 * 4) + 3)] = (C_local[((i_3 * 4) + 3)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 63)] * B_shared[((((int)threadIdx.x) & 31) + 960)]));
#       C_local[((i_3 * 4) + 19)] = (C_local[((i_3 * 4) + 19)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 63)] * B_shared[((((int)threadIdx.x) & 31) + 992)]));
#       C_local[((i_3 * 4) + 35)] = (C_local[((i_3 * 4) + 35)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2111)] * B_shared[((((int)threadIdx.x) & 31) + 960)]));
#       C_local[((i_3 * 4) + 51)] = (C_local[((i_3 * 4) + 51)] + (A_shared[((((((int)threadIdx.x) >> 5) * 256) + (i_3 * 64)) + 2111)] * B_shared[((((int)threadIdx.x) & 31) + 992)]));
#     }
#   }
#   C[(((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31))] = C_local[0];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 32)] = C_local[16];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 131072)] = C_local[32];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 131104)] = C_local[48];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 1024)] = C_local[1];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 1056)] = C_local[17];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 132096)] = C_local[33];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 132128)] = C_local[49];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 2048)] = C_local[2];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 2080)] = C_local[18];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 133120)] = C_local[34];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 133152)] = C_local[50];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 3072)] = C_local[3];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 3104)] = C_local[19];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 134144)] = C_local[35];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 134176)] = C_local[51];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 4096)] = C_local[4];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 4128)] = C_local[20];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 135168)] = C_local[36];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 135200)] = C_local[52];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 5120)] = C_local[5];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 5152)] = C_local[21];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 136192)] = C_local[37];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 136224)] = C_local[53];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 6144)] = C_local[6];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 6176)] = C_local[22];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 137216)] = C_local[38];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 137248)] = C_local[54];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 7168)] = C_local[7];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 7200)] = C_local[23];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 138240)] = C_local[39];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 138272)] = C_local[55];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 8192)] = C_local[8];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 8224)] = C_local[24];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 139264)] = C_local[40];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 139296)] = C_local[56];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 9216)] = C_local[9];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 9248)] = C_local[25];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 140288)] = C_local[41];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 140320)] = C_local[57];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 10240)] = C_local[10];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 10272)] = C_local[26];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 141312)] = C_local[42];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 141344)] = C_local[58];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 11264)] = C_local[11];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 11296)] = C_local[27];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 142336)] = C_local[43];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 142368)] = C_local[59];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 12288)] = C_local[12];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 12320)] = C_local[28];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 143360)] = C_local[44];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 143392)] = C_local[60];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 13312)] = C_local[13];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 13344)] = C_local[29];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 144384)] = C_local[45];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 144416)] = C_local[61];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 14336)] = C_local[14];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 14368)] = C_local[30];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 145408)] = C_local[46];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 145440)] = C_local[62];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 15360)] = C_local[15];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 15392)] = C_local[31];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 146432)] = C_local[47];
#   C[((((((((int)blockIdx.x) >> 4) * 262144) + ((((int)threadIdx.x) >> 5) * 16384)) + ((((int)blockIdx.x) & 15) * 64)) + (((int)threadIdx.x) & 31)) + 146464)] = C_local[63];
# }
